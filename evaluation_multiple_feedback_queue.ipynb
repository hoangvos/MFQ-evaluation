# %%
''' ------------------------ '''
''' Dependencies             '''
''' ------------------------ '''
import simpy
import statistics 
import numpy.random as random
from numpy import *
import matplotlib.pyplot as plt
from kneed import DataGenerator, KneeLocator
from pyDOE import *
import pandas as pd

# %%
''' ------------------------ '''
''' Running mode, Only one   '''
''' option should be True    '''
''' ------------------------ '''
#One time simulation for short demonstration
DEMO = False                 
#Multiple simulations to get mean value 
MULTIPLE_SIMULATION = False
#Again, multiple simulations for experiments
EXPERIMENT = True
# Experiment running for the QUANTUM effect
EXPERIMENT_QUANTUM_On_FIRST_RESPONSE = False

# %%
''' ------------------------ '''
''' Experiment list          '''
''' 2 level only              '''
''' ------------------------ '''
lambda_exp = [0.025, 0.05]
mu_exp = [0.1, 0.2]
quantum_exp = [0.3, 3]

# %%
''' ------------------------ '''
''' Parameters               '''
''' ------------------------ '''
MAXSIMTIME = 1000000
LAMBDA = 0.2
MU = 0.1
LAMBDA_IO = 0.5
MU_IO = 0.5
IO_PROBALITIES = 0.2
QUANTUM_QUEUE_1 = 4
QUANTUM_QUEUE_2 = 8
POPULATION = 50000000
SERVICE_DISCIPLINE = 'RR'
LOGGED = False 
VERBOSE = True
NSIM = 30
NUM_CPU = 3

# %%
''' ------------------------ '''
''' DES model                '''
''' ------------------------ '''
# This is for data recording, haven't use anything yet
# may come handy later so I left it there
class Record:
    total_burst = []   # sum of burst times at each step
    total_hist_t = []  # step at which burst total was recorded
    q_size = []        # size of queue at each step
    q_time = []        # step at which queue size was recorded
    times = []
    mean_burst = []
    wait_t = []
    trnd_t = []
    mean_wait = []
    mean_trnd = []
    arrivals = []      # arrival times of jobs
    finish = []        # finish time of jobs
class Job:
    def __init__(self,server, name, arrtime, duration, remain, allotment, first_response, priority, io, lam_io, mu_io):
        self.server = server
        self.env = self.server.env
        self.io = io
        self.lam_io = lam_io
        self.mu_io = mu_io
        self.priority = priority
        self.name = name
        self.arrtime = arrtime
        self.service_t = duration
        self.remain_t = remain
        self.allotment = allotment
        self.first_response = first_response
        self.wait_t = 0
        self.trnd_t = 0
        self.resp_t = 0
        self.io_trigger = simpy.Event(self.server.env)
        self.io_service_t = 0
        self.io_arrtime = 0
        self.past_queue = 1
        self.processing_job = simpy.Event(self.env)
        self.processing = simpy.Event(self.env)
        self.processing = simpy.Event(self.env)
        self.trigger_event_source = simpy.Event(env)

    def __str__(self):
        return '%s at %d, length %d' %(self.name, self.arrtime, self.duration)

def SJF( job ):
    return job.duration

''' 
A server
- env: SimPy environment
- strat: - FIFO: First In First Out
         - SJF : Shortest Job First
         - RR: Round-robin
'''
class Server:
    def __init__(self, env, strat = 'RR'):
        self.env = env
        """ Create resources """
        self.cpu = simpy.PreemptiveResource(env, capacity = NUM_CPU)
        """ Create resources """
 
        
        self.strat = strat
        self.queue_1 = []
        self.queue_2 = []
        self.queue_3 = []
        self.io_queue = []
        self.jobServing = 0
        
        self.serversleeping = None
        self.server_io_request = None
        
        ''' statistics '''
        self.waitingTime = 0
        self.jobsDone = 0
        self.serviceTime = 0
        self.responseTime = 0
        self.first_responsetime = 0     # accumulating the first response time
        self.turnaroundTime = 0
        self.timeStamp = 0
        self.jobsTotal = 0              # total jobs had been first responsed
        self.jobsInSysCount = []        # record number of current jobs in the system
        self.jobsInSysCount_t = []      # mark down the time when record occurs
        self.numJobsWithTimes = []      # for mean job in system calculation. don't judge the name tho :(
        
        self.job_in_sys_count = []      # try to count the number of job in sys with even length time
        self.job_in_sys_count_avg = []  # number of job in sys * time length
        self.length = []                # list to store the type of length of queue

        ''' register a new server process '''
        env.process(self.serve())
        env.process(self.timeout())
        env.process(self.handle_io_request())
    def handle_io_request(self):
        while True:
            if len(self.io_queue) == 0:
                self.server_io_request = self.env.process(self.waiting_io(self.env))
                yield self.server_io_request
            else:
                j = self.io_queue.pop(0)
                self.jobServing += 1
                if VERBOSE:
                    print('{0:.2f}: {1:s} is implementing IO.'.format(self.env.now, j.name))
                yield self.env.timeout(j.io_service_t)
                self.jobServing -= 1
                j.service_t += j.io_service_t
                if VERBOSE:
                    print('{0:.2f}: IO finished, {1:s} returns back to queue {2:d}.'.format(self.env.now, j.name, j.past_queue))
                if j.past_queue == 1:
                    self.queue_1.append(j) 
                elif j.past_queue == 2:
                    self.queue_2.append(j)
                elif j.past_queue == 3:
                    self.queue_3.append(j)
                
    def serve(self):
        while True:
            ''' 
            do nothing, just change server to idle
            and then yield a wait event which takes infinite time
            '''
            if len(self.queue_1) == 0 and len(self.queue_2) == 0 and len(self.queue_3) == 0:
                self.serversleeping = env.process( self.waiting( self.env))
                yield self.serversleeping
            else:
                ''' 
                record the number of job in system:
                number of job in waiting queue (jobs)
                '''
                if VERBOSE:
                    print('Number of jobs in the sys: {0:d}' .format(len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + len(self.io_queue) + self.jobServing))
                    print('Queued 1: ')
                    for i in range(len(self.queue_1)):
                            print(self.queue_1[i].name, end=" | ")
                    print('\n')
                    print('Queued 2: ')
                    for i in range(len(self.queue_2)):
                            print(self.queue_2[i].name, end=" | ")
                    print('\n')
                    print('Queued 3: ')
                    for i in range(len(self.queue_3)):
                            print(self.queue_3[i].name, end=" | ")
                    print('\n')
                    print('IO queue: ')
                    for i in range(len(self.io_queue)):
                            print(self.io_queue[i].name, end=" | ")
                    print('\n')
                ''' get the first job to be served'''
                if len(self.queue_1) > 0:
                    with self.cpu.request(priority = 1) as req:
                        try:
                            yield req
                            if len(self.queue_1) > 0:
                                j = self.queue_1.pop(0)
                            else:
                                continue
                        except simpy.Interrupt as interrupt:
                            continue 
                    self.env.process(self.handle_queue_1(j))
                    yield j.trigger_event_source
                elif len(self.queue_2) > 0:
                    with self.cpu.request(priority = 2) as req:
                        try:
                            yield req
                            if len(self.queue_2) > 0:
                                j = self.queue_2.pop(0)
                            else:
                                continue
                        except simpy.Interrupt as interrupt:
                            continue 
                    self.env.process(self.handle_queue_2(j))
                    yield j.trigger_event_source
                elif len(self.queue_3) > 0:
                    with self.cpu.request(priority = 3) as req:
                        try:
                            yield req
                            if len(self.queue_3) > 0:
                                j = self.queue_3.pop(0)
                            else:
                                continue
                        except simpy.Interrupt as interrupt:
                            continue 
                    self.env.process(self.handle_queue_3(j))
                    yield j.trigger_event_source
    def handle_queue_1(self, job):
        print("Enter handle 1")
        with self.cpu.request(priority = job.priority) as req:
            try:
                yield req 
            except simpy.Interrupt as interrupt:
                return 0
            try:
                if job.io:
                    self.env.process(self.generate_io(job))   
                job.trigger_event_source.succeed()
                job.trigger_event_source = simpy.Event(env)
                current_time = self.env.now
                self.jobServing += 1
                if LOGGED:
                    qlog.write( '%.4f\t%d\t%d\n' % (self.env.now, 1 if len(self.queue_1)>0 else 0, len(self.queue_1)) )
                if job.first_response:
                    self.jobsTotal += 1
                    current_t = self.env.now
                    self.first_responsetime += (current_t - job.arrtime)
                    job.first_response = 0
                    if VERBOSE:
                        print("{0:.2f} {1:s} first response time: {2:.2f}".format(env.now, job.name, env.now - job.arrtime))
                    """ if the job is stopped (quantum expired)"""
                if job.remain_t > job.allotment:
                    if VERBOSE:
                        print('Queued 1: ')
                        for i in range(len(self.queue_1)):
                            print(self.queue_1[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' \
                            .format(env.now, job.name, job.arrtime, job.remain_t))
                    timeout_event = self.env.timeout(job.allotment)
                    result = yield timeout_event | job.processing_job
                    
                    if timeout_event not in result:
                        #print(env.now)
                        #print('aaaaaaaaaaaaaaaaa')
                        job.remain_t -= (env.now - current_time)
                        job.allotment -= (env.now - current_time)
                        job.past_queue = 1
                        self.jobServing -= 1
                        return
                    job.processing.succeed()
                    job.processing = simpy.Event(self.env)
                    
                    job.remain_t = job.remain_t - job.allotment
                    job.allotment = QUANTUM_QUEUE_2 if job.remain_t >= QUANTUM_QUEUE_2 else job.remain_t
                    job.priority += 1 
                    self.jobServing -= 1 
                    self.queue_2.append(job)
                    if not self.serversleeping.triggered:
                        self.serversleeping.interrupt( 'Wake up, please.' )
                elif job.remain_t == job.allotment:
                    if VERBOSE:
                        print('Queued 1: ')
                        for i in range(len(self.queue_1)):
                            print(self.queue_1[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}'.format(env.now, job.name, job.arrtime, job.remain_t))
        
                    
                    

                    timeout_event = self.env.timeout(job.remain_t)
                    result = yield timeout_event | job.processing_job
                    if timeout_event not in result:
                        #print(env.now)
                        #print('aaaaaaaaaaaaaaaaa')
                        job.remain_t -= (env.now - current_time)
                        job.allotment -= (env.now - current_time)
                        self.jobServing -= 1
                        job.past_queue = 1
                        return
                    job.processing.succeed()
                    job.processing = simpy.Event(self.env)
                    ''' for calculating mean of job in system'''
                    ''' right before the job leaves          '''
                    ''' like 2 2 2 2 2 2 1                   '''
                    ''' mark at this   ^                     '''
                    self.jobServing -= 1
                    elapse = self.env.now - self.timeStamp
                    queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + len(self.io_queue) + self.jobServing + 1
                    self.numJobsWithTimes.append((queueLength)*(elapse))
                    self.jobsInSysCount.append(queueLength)
                    self.jobsInSysCount_t.append(env.now)
                    self.timeStamp = self.env.now
                    finishTime = env.now
                    job.wait_t = finishTime - job.arrtime - job.service_t
                    job.trnd_t = finishTime - job.arrtime
                    self.waitingTime += job.wait_t
                    self.serviceTime += job.service_t
                    self.turnaroundTime += job.trnd_t
                    self.jobsDone += 1
                    if VERBOSE:
                        print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                            .format(finishTime, job.trnd_t, job.wait_t))
                        print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(env.now,queueLength - 1))
            except simpy.Interrupt as interrupt:
                #print(interrupt)
                job.processing.succeed()
                job.processing = simpy.Event(self.env)
                pass_time = env.now - current_time
                if VERBOSE:
                    print('Queued 1: ')
                    for i in range(len(self.queue_1)):
                        print(self.queue_1[i].name, end=" | ")
                    print('\n')
                    print('{0:s} is preempted at {1:.2f}. The remaining allotment is {2:.2f}'.format(job.name, env.now, job.remain_t - pass_time))
                if env.now - current_time == job.allotment: 
                    if job.remain_t > job.allotment:
                        job.remain_t = job.remain_t - job.allotment
                        job.allotment = QUANTUM_QUEUE_2 if job.remain_t >= QUANTUM_QUEUE_2 else job.remain_t
                        job.priority += 1
                        self.jobServing -= 1
                        self.queue_2.append(job)
                        if not self.serversleeping.triggered:
                            self.serversleeping.interrupt( 'Wake up, please.' )
                    elif job.remain_t == job.allotment:
                        self.jobServing -= 1
                        elapse = self.env.now - self.timeStamp
                        queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + len(self.io_queue) + self.jobServing + 1
                        self.numJobsWithTimes.append((queueLength)*(elapse))
                        self.jobsInSysCount.append(queueLength)
                        self.jobsInSysCount_t.append(env.now)
                        self.timeStamp = self.env.now
                        finishTime = env.now
                        job.wait_t = finishTime - job.arrtime - job.service_t
                        job.trnd_t = finishTime - job.arrtime
                        self.waitingTime += job.wait_t
                        self.serviceTime += job.service_t
                        self.turnaroundTime += job.trnd_t
                        self.jobsDone += 1
                        if VERBOSE:
                            print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                                .format(finishTime, job.trnd_t, job.wait_t))
                            print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(env.now,queueLength - 1))
                        
                else:
                    self.jobServing -= 1
                    job.allotment -= pass_time
                    job.remain_t -= pass_time
                    self.queue_1.append(job)
    # End handle_queue_1
    
    def handle_queue_2(self, job):    
        print("Enter handle 2")
        with self.cpu.request(priority = job.priority) as req:
            try:
                yield req 
            except simpy.Interrupt as interrupt:
                return 0
            try:
                job.trigger_event_source.succeed()
                job.trigger_event_source = simpy.Event(env)
                current_time = self.env.now
                if job.io:
                    self.env.process(self.generate_io(job))
                self.jobServing += 1
                if LOGGED:
                    qlog.write( '%.4f\t%d\t%d\n' % (self.env.now, 1 if len(self.queue_2)>0 else 0, len(self.queue_2)) )
                if job.first_response:
                    self.jobsTotal += 1
                    current_t = self.env.now
                    self.first_responsetime += (current_t - job.arrtime)
                    job.first_response = 0
                    if VERBOSE:
                        print("{0:.2f} {1:s} first response time: {2:.2f}".format(env.now, job.name, env.now - job.arrtime))
                    """ if the job is stopped (quantum expired)"""
                if job.remain_t > job.allotment:
                    if VERBOSE:
                        print('Queued 2: ')
                        for i in range(len(self.queue_2)):
                            print(self.queue_2[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' \
                            .format(env.now, job.name, job.arrtime, job.remain_t))
                    timeout_event = self.env.timeout(job.allotment)
                    result = yield timeout_event | job.processing_job
                    if timeout_event not in result:
                        #print(env.now)
                        #print('aaaaaaaaaaaaaaaaa')
                        job.remain_t -= (env.now - current_time)
                        job.allotment -= (env.now - current_time)
                        self.jobServing -= 1
                        job.past_queue = 2
                        return
                    job.processing.succeed()
                    job.processing = simpy.Event(self.env)
                    job.remain_t = job.remain_t - job.allotment
                    job.allotment = job.remain_t
                    job.priority += 1
                    self.jobServing -= 1
                    self.queue_3.append(job)
                    if not self.serversleeping.triggered:
                        self.serversleeping.interrupt( 'Wake up, please.' )
                elif job.remain_t == job.allotment:
                    if VERBOSE:
                        print('Queued 2: ')
                        for i in range(len(self.queue_2)):
                            print(self.queue_2[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' .format(self.env.now, job.name, job.arrtime, job.remain_t))
                    timeout_event = self.env.timeout(job.remain_t)
                    result = yield timeout_event | job.processing_job
                    if timeout_event not in result:
                        #print(env.now)
                        #print('aaaaaaaaaaaaaaaaa')
                        job.remain_t -= (env.now - current_time)
                        job.allotment -= (env.now - current_time)
                        self.jobServing -= 1
                        job.past_queue = 2
                        return
                    job.processing.succeed()
                    job.processing = simpy.Event(self.env)
                    self.jobServing -= 1
                    ''' for calculating mean of job in system'''
                    ''' right before the job leaves          '''
                    ''' like 2 2 2 2 2 2 1                   '''
                    ''' mark at this   ^                     '''
                    elapse = self.env.now - self.timeStamp
                    queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + len(self.io_queue) + self.jobServing + 1
                    self.numJobsWithTimes.append((queueLength)*(elapse))
                    self.jobsInSysCount.append(queueLength)
                    self.jobsInSysCount_t.append(env.now)
                    self.timeStamp = self.env.now
                    finishTime = env.now
                    job.wait_t = finishTime - job.arrtime - job.service_t
                    job.trnd_t = finishTime - job.arrtime
                    self.waitingTime += job.wait_t
                    self.serviceTime += job.service_t
                    self.turnaroundTime += job.trnd_t
                    self.jobsDone += 1
                    if VERBOSE:
                        print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                            .format(finishTime, job.trnd_t, job.wait_t))
                        print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(env.now,queueLength - 1))
            except simpy.Interrupt as interrupt:
                #print(interrupt)
                job.processing.succeed() 
                job.processing = simpy.Event(self.env)
                pass_time = env.now - current_time
                if VERBOSE:
                    print('Queued 2: ')
                    for i in range(len(self.queue_2)):
                        print(self.queue_2[i].name, end=" | ")
                    print('\n')
                    print('{0:s} is preempted at {1:.2f}. The remaining allotment is {2:.2f}'.format(job.name, env.now, job.remain_t - pass_time))
                if env.now - current_time == job.allotment:
                    if job.remain_t > job.allotment:
                        job.remain_t = job.remain_t - job.allotment
                        job.allotment = job.remain_t
                        job.priority += 1
                        self.jobServing -= 1
                        self.queue_3.append(job)
                        if not self.serversleeping.triggered:
                            self.serversleeping.interrupt( 'Wake up, please.' )
                    elif job.remain_t == job.allotment:
                        self.jobServing -= 1
                        elapse = self.env.now - self.timeStamp
                        queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + len(self.io_queue) + self.jobServing + 1
                        self.numJobsWithTimes.append((queueLength)*(elapse))
                        self.jobsInSysCount.append(queueLength)
                        self.jobsInSysCount_t.append(env.now)
                        self.timeStamp = self.env.now
                        finishTime = env.now
                        job.wait_t = finishTime - job.arrtime - job.service_t
                        job.trnd_t = finishTime - job.arrtime
                        self.waitingTime += job.wait_t
                        self.serviceTime += job.service_t
                        self.turnaroundTime += job.trnd_t
                        self.jobsDone += 1
                        if VERBOSE:
                            print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                                .format(finishTime, job.trnd_t, job.wait_t))
                            print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(self.env.now,queueLength - 1))
                else:
                    self.jobServing -= 1
                    job.allotment -= pass_time
                    job.remain_t -= pass_time
                    self.queue_2.append(job)
    def handle_queue_3(self, job):   
        print("Enter handle 3")
        
        with self.cpu.request(priority = job.priority) as req:
            try:
                yield req 
            except simpy.Interrupt as interrupt:
                return 0
            try:
                job.trigger_event_source.succeed()
                job.trigger_event_source = simpy.Event(env)
                current_time = self.env.now
                self.jobServing += 1
                if job.io:
                    self.env.process(self.generate_io(job))
                if LOGGED:
                    qlog.write( '%.4f\t%d\t%d\n' % (self.env.now, 1 if len(self.queue_3)>0 else 0, len(self.queue_3)) )
                if job.first_response:
                    self.jobsTotal += 1
                    current_t = self.env.now
                    self.first_responsetime += (current_t - job.arrtime)
                    job.first_response = 0
                    if VERBOSE:
                        print("{0:.2f} {1:s} first response time: {2:.2f}".format(env.now, job.name, env.now - job.arrtime))
                    """ if the job is stopped (quantum expired)"""
                if job.remain_t > job.allotment:
                    if VERBOSE:
                        print('Queued 3: ')
                        for i in range(len(self.queue_3)):
                            print(self.queue_3[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' \
                            .format(self.env.now, job.name, job.arrtime, job.remain_t))
                    timeout_event = self.env.timeout(job.allotment)
                    result = yield timeout_event | job.processing_job
                    if timeout_event not in result:
                        #print(env.now)
                        #print('aaaaaaaaaaaaaaaaa')
                        job.remain_t -= (env.now - current_time)
                        job.allotment -= (env.now - current_time)
                        self.jobServing -= 1
                        job.past_queue = 3
                        return
                    job.processing.succeed()
                    job.processing = simpy.Event(self.env)
                    
                    job.remain_t = job.remain_t - job.allotment
                    job.allotment = job.remain_t
                    job.priority += 1
                    self.jobServing -= 1
                    self.queue_3.append(job)
                    if not self.serversleeping.triggered:
                        self.serversleeping.interrupt( 'Wake up, please.' )
                elif job.remain_t == job.allotment:
                    if VERBOSE:
                        print('Queued 3: ')
                        for i in range(len(self.queue_3)):
                            print(self.queue_3[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' .format(env.now, job.name, job.arrtime, job.remain_t))
                
                    timeout_event = self.env.timeout(job.remain_t)
                    result = yield timeout_event  | job.processing_job
                    if timeout_event not in result:
                        #print(env.now)
                        #print('aaaaaaaaaaaaaaaaa')
                        job.remain_t -= (env.now - current_time)
                        job.allotment -= (env.now - current_time)
                        self.jobServing -= 1
                        job.past_queue = 3
                        return
                    job.processing.succeed()
                    job.processing = simpy.Event(self.env)
                    
                    self.jobServing -= 1
                    ''' for calculating mean of job in system'''
                    ''' right before the job leaves          '''
                    ''' like 2 2 2 2 2 2 1                   '''
                    ''' mark at this   ^                     '''
                    
                    
                    
                    elapse = self.env.now - self.timeStamp
                    queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + len(self.io_queue) + self.jobServing + 1
                    self.numJobsWithTimes.append((queueLength)*(elapse))
                    self.jobsInSysCount.append(queueLength)
                    self.jobsInSysCount_t.append(env.now)
                    self.timeStamp = self.env.now
                    finishTime = env.now
                    job.wait_t = finishTime - job.arrtime - job.service_t
                    job.trnd_t = finishTime - job.arrtime
                    self.waitingTime += job.wait_t
                    self.serviceTime += job.service_t
                    self.turnaroundTime += job.trnd_t
                    self.jobsDone += 1
                    if VERBOSE:
                        print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                            .format(finishTime, job.trnd_t, job.wait_t))
                        print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(self.env.now,queueLength - 1))
            except simpy.Interrupt as interrupt:
                #print(interrupt)
                job.processing.succeed()
                job.processing = simpy.Event(self.env)
                pass_time = env.now - current_time
                if VERBOSE:
                    print('Queued 3: ')
                    for i in range(len(self.queue_3)):
                        print(self.queue_3[i].name, end=" | ")
                    print('\n')
                    print('{0:s} is preempted at {1:.2f}. The remaining allotment is {2:.2f}'.format(job.name, env.now, job.remain_t - pass_time))
                if env.now - current_time == job.allotment:
                    if job.remain_t > job.allotment:
                        job.remain_t = job.remain_t - job.allotment
                        job.allotment = job.remain_t
                        job.priority += 1
                        self.jobServing -= 1
                        self.queue_3.append(job)
                        if not self.serversleeping.triggered:
                            self.serversleeping.interrupt( 'Wake up, please.' )
                    elif job.remain_t == job.allotment:
                        self.jobServing -= 1
                        elapse = self.env.now - self.timeStamp
                        queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + len(self.io_queue) + self.jobServing + 1
                        self.numJobsWithTimes.append((queueLength)*(elapse))
                        self.jobsInSysCount.append(queueLength)
                        self.jobsInSysCount_t.append(env.now)
                        self.timeStamp = self.env.now
                        finishTime = env.now
                        job.wait_t = finishTime - job.arrtime - job.service_t
                        job.trnd_t = finishTime - job.arrtime
                        self.waitingTime += job.wait_t
                        self.serviceTime += job.service_t
                        self.turnaroundTime += job.trnd_t
                        self.jobsDone += 1
                        if VERBOSE:
                            print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                                .format(finishTime, job.trnd_t, job.wait_t))
                            print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(self.env.now,queueLength - 1))    
                else:
                    self.jobServing -= 1
                    job.allotment -= pass_time
                    job.remain_t -= pass_time
                    self.queue_3.append(job)
    def generate_io(self, job):
        current_time = env.now
        io_interarrival = (random.exponential(1/job.lam_io))
        timeout_event = self.env.timeout(io_interarrival)
        result = yield timeout_event | job.processing
        if timeout_event not in result:
            #print(env.now)
            #print('aaaaaaaaaaaaaaaaa1')
            return
        job.processing_job.succeed()
        job.processing_job = simpy.Event(self.env)
        job.io_arrtime = self.env.now
        job.io_service_t = (random.exponential(1/job.mu_io))
        self.io_queue.append(job)
        if VERBOSE:
            print('{0:.2f} IO request: {1:s} | inter-arr_t = {2:.2f} | l = {3:.2f}' \
                .format(self.env.now, job.name, job.io_arrtime , job.io_service_t))
        if not self.server_io_request.triggered:
            self.server_io_request.interrupt()
    def waiting(self, env):
        try:
            if VERBOSE:
                print( 'Server is idle at %.2f' % self.env.now )
            yield self.env.timeout( MAXSIMTIME )
        except simpy.Interrupt as i:
            if VERBOSE:
                 print('Server waken up and works at %.2f' % self.env.now )
    def waiting_io(self, env):
        try:
            yield self.env.timeout( MAXSIMTIME )
        except simpy.Interrupt as i:
            if VERBOSE:
                print("IO request at %.2f" % self.env.now)
    def timeout(self):
        while True:
            yield self.env.timeout(100)
            for job in self.queue_2:
                job.priority = 1
            for job in self.queue_3:
                job.priority = 1
            self.queue_1 = self.queue_3 + self.queue_2 + self.queue_1
            self.queue_2.clear()
            self.queue_3.clear()
            if VERBOSE:
                print("TIME OUT !!!")
                print('Number of jobs in the sys: {0:d}' .format(len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing))
                print('Queued 1: ')
                for i in range(len(self.queue_1)):
                        print(self.queue_1[i].name, end=" | ")
                print('\n')
                print('Queued 2: ')
                for i in range(len(self.queue_2)):
                        print(self.queue_2[i].name, end=" | ")
                print('\n')
                print('Queued 3: ')
                for i in range(len(self.queue_3)):
                        print(self.queue_3[i].name, end=" | ")
                print('\n')

class JobGenerator:
    def __init__(self, env, server, nrjobs = 10000000, lam = 5, mu = 6, lam_io = 8, mu_io = 8, io_probability=0.3):
        self.server = server
        self.nrjobs = nrjobs
        self.interarrivaltime = 1/lam
        self.servicetime = 1/mu
        env.process(self.generatejobs(env) )
        env.process(self.job_log(env))
        self.lam_io = lam_io
        self.mu_io = mu_io 
        self.io_probability = io_probability

    def generatejobs(self, env):
        i = 1
        while True:
            ''' yield an event for new job arrival'''
            job_interarrival = (random.exponential( self.interarrivaltime ))
            yield env.timeout( job_interarrival )

            ''' for calculate mean number of job in system'''
            ''' before the job come                       '''
            ''' like  0 0 0 0 0 1                         '''
            ''' mark at this  ^                           '''
            elapse = env.now-self.server.timeStamp
            queueLength = len(self.server.queue_1) +len(self.server.queue_2)+len(self.server.queue_3) + len(self.server.io_queue) + self.server.jobServing
            self.server.numJobsWithTimes.append((queueLength)*(elapse))
            self.server.jobsInSysCount.append(queueLength)
            self.server.jobsInSysCount_t.append(env.now)
            self.server.timeStamp = env.now

            ''' generate service time and add job to the list'''
            job_duration = (random.exponential( self.servicetime))
            io = random.uniform(0, 1) < self.io_probability
            self.server.queue_1.append( Job(self.server, 'Job %s' %i, env.now, job_duration, job_duration, job_duration if job_duration < QUANTUM_QUEUE_1 else QUANTUM_QUEUE_1 , 1, 1, io, self.lam_io, self.mu_io) )

            if VERBOSE:
                print('{0:.2f} arrive: Job {1:d} | inter-arr_t = {2:.2f} | l = {3:.2f}' \
                    .format(env.now, i, job_interarrival, job_duration))
                print('{0:.2f} Number of job in the system is sampled at arrival:  {1:d}'.format(env.now,queueLength))
                print('Time elapsed form last sample:           {0:.2f}'.format(elapse))
            i += 1

            ''' if server is idle, wake it up'''
            if not self.server.serversleeping.triggered:
                self.server.serversleeping.interrupt( 'Wake up, please.' )

    def job_log(self, env):
        while True:
            if (len(self.server.queue_1) + len(self.server.queue_2) + len(self.server.queue_3) + self.server.jobServing) not in self.server.length:
                self.server.length.append(len(self.server.queue_1) + len(self.server.queue_2) + len(self.server.queue_3) + self.server.jobServing)
            self.server.job_in_sys_count.append(len(self.server.queue_1) + len(self.server.queue_2) + len(self.server.queue_3) + self.server.jobServing)
            yield env.timeout(1)

# %%
env = simpy.Environment()
MyServer = Server( env, SERVICE_DISCIPLINE )
MyJobGenerator = JobGenerator( env, MyServer, POPULATION, LAMBDA, MU, LAMBDA_IO, MU_IO, IO_PROBALITIES)

''' start simulation '''
env.run( until = 400)
# Out:
# Server is idle at 0.00
# 2.64 arrive: Job 1 | inter-arr_t = 2.64 | l = 5.02
# 2.64 Number of job in the system is sampled at arrival:  0
# Time elapsed form last sample:           2.64
# Server waken up and works at 2.64
# Number of jobs in the sys: 1
# Queued 1:
# Job 1 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 2.64 Job 1 first response time: 0.00
# Queued 1:
#
#
# 2.64 serving:Job 1 | arr_t = 2.64 | l = 5.02
# Server is idle at 2.64
# 2.77 IO request: Job 1 | inter-arr_t = 2.77 | l = 0.77
# IO request at 2.77
# 2.77: Job 1 is implementing IO.
# 3.54: IO finished, Job 1 returns back to queue 1.
# 12.38 arrive: Job 2 | inter-arr_t = 9.74 | l = 3.84
# 12.38 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           9.74
# Server waken up and works at 12.38
# Number of jobs in the sys: 2
# Queued 1:
# Job 1 | Job 2 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 2 |
#
# 12.38 serving:Job 1 | arr_t = 2.64 | l = 4.90
# Number of jobs in the sys: 2
# Queued 1:
# Job 2 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 12.38 Job 2 first response time: 0.00
# Queued 1:
#
#
# 12.38 serving:Job 2 | arr_t = 12.38 | l = 3.84
# Server is idle at 12.38
# 13.06 IO request: Job 1 | inter-arr_t = 13.06 | l = 2.22
# IO request at 13.06
# 13.06: Job 1 is implementing IO.
# 14.43 arrive: Job 3 | inter-arr_t = 2.05 | l = 3.98
# 14.43 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           2.05
# Server waken up and works at 14.43
# Number of jobs in the sys: 3
# Queued 1:
# Job 3 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 14.43 Job 3 first response time: 0.00
# Queued 1:
#
#
# 14.43 serving:Job 3 | arr_t = 14.43 | l = 3.98
# Server is idle at 14.43
# 15.27: IO finished, Job 1 returns back to queue 1.
# Job 2: Finish at 16.22, trnd_t = 3.84, wait_t = -0.00
# 16.22 Number of jobs in the system at the time a job finished: 2
# 17.03 arrive: Job 4 | inter-arr_t = 2.60 | l = 10.55
# 17.03 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           0.81
# Server waken up and works at 17.03
# Number of jobs in the sys: 3
# Queued 1:
# Job 1 | Job 4 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 4 |
#
# 17.03 serving:Job 1 | arr_t = 2.64 | l = 4.22
# Number of jobs in the sys: 3
# Queued 1:
# Job 4 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 17.03 Job 4 first response time: 0.00
# Queued 1:
#
#
# 17.03 serving:Job 4 | arr_t = 17.03 | l = 10.55
# Server is idle at 17.03
# 17.14 IO request: Job 1 | inter-arr_t = 17.14 | l = 4.50
# IO request at 17.14
# 17.14: Job 1 is implementing IO.
# 17.42 IO request: Job 4 | inter-arr_t = 17.42 | l = 1.06
# Job 3: Finish at 18.41, trnd_t = 3.98, wait_t = 0.00
# 18.41 Number of jobs in the system at the time a job finished: 2
# 19.73 arrive: Job 5 | inter-arr_t = 2.70 | l = 2.81
# 19.73 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           1.32
# Server waken up and works at 19.73
# Number of jobs in the sys: 3
# Queued 1:
# Job 5 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 4 |
#
# Enter handle 1
# 19.73 Job 5 first response time: 0.00
# Queued 1:
#
#
# 19.73 serving:Job 5 | arr_t = 19.73 | l = 2.81
# Server is idle at 19.73
# 20.22 arrive: Job 6 | inter-arr_t = 0.49 | l = 15.89
# 20.22 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           0.49
# Server waken up and works at 20.22
# Number of jobs in the sys: 4
# Queued 1:
# Job 6 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 4 |
#
# Enter handle 1
# 20.22 Job 6 first response time: 0.00
# Queued 1:
#
#
# 20.22 serving:Job 6 | arr_t = 20.22 | l = 15.89
# Server is idle at 20.22
# 20.81 arrive: Job 7 | inter-arr_t = 0.59 | l = 3.55
# 20.81 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           0.59
# Server waken up and works at 20.81
# Number of jobs in the sys: 5
# Queued 1:
# Job 7 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 4 |
#
# Enter handle 1
# 20.81 Job 7 first response time: 0.00
# Queued 1:
#
#
# 20.81 serving:Job 7 | arr_t = 20.81 | l = 3.55
# Server is idle at 20.81
# 20.85 IO request: Job 7 | inter-arr_t = 20.85 | l = 3.71
# 21.11 arrive: Job 8 | inter-arr_t = 0.30 | l = 0.52
# 21.11 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           0.30
# Server waken up and works at 21.11
# Number of jobs in the sys: 6
# Queued 1:
# Job 8 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 4 | Job 7 |
#
# Enter handle 1
# 21.11 Job 8 first response time: 0.00
# Queued 1:
#
#
# 21.11 serving:Job 8 | arr_t = 21.11 | l = 0.52
# Server is idle at 21.11
# Job 8: Finish at 21.63, trnd_t = 0.52, wait_t = 0.00
# 21.63 Number of jobs in the system at the time a job finished: 5
# 21.64: IO finished, Job 1 returns back to queue 1.
# 21.64: Job 4 is implementing IO.
# Job 5: Finish at 22.54, trnd_t = 2.81, wait_t = -0.00
# 22.54 Number of jobs in the system at the time a job finished: 4
# 22.70: IO finished, Job 4 returns back to queue 1.
# 22.70: Job 7 is implementing IO.
# 22.90 arrive: Job 9 | inter-arr_t = 1.79 | l = 2.26
# 22.90 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           0.36
# Server waken up and works at 22.90
# Number of jobs in the sys: 5
# Queued 1:
# Job 1 | Job 4 | Job 9 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 4 | Job 9 |
#
# 22.90 serving:Job 1 | arr_t = 2.64 | l = 4.11
# Number of jobs in the sys: 5
# Queued 1:
# Job 4 | Job 9 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 9 |
#
# 22.90 serving:Job 4 | arr_t = 17.03 | l = 10.16
# Number of jobs in the sys: 5
# Queued 1:
# Job 9 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# 24.17 IO request: Job 1 | inter-arr_t = 24.17 | l = 4.95
# Enter handle 1
# 24.17 Job 9 first response time: 1.27
# Queued 1:
#
#
# 24.17 serving:Job 9 | arr_t = 22.90 | l = 2.26
# Server is idle at 24.17
# Server waken up and works at 24.22
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 6 |
#
# Queued 3:
#
#
# IO queue:
# Job 1 |
#
# Enter handle 2
# Queued 2:
#
#
# 24.22 serving:Job 6 | arr_t = 20.22 | l = 11.89
# Server is idle at 24.22
# 26.40: IO finished, Job 7 returns back to queue 1.
# 26.40: Job 1 is implementing IO.
# Job 9: Finish at 26.43, trnd_t = 3.53, wait_t = 1.27
# 26.43 Number of jobs in the system at the time a job finished: 4
# Server waken up and works at 26.51
# Number of jobs in the sys: 4
# Queued 1:
# Job 7 |
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
#
#
# 26.51 serving:Job 7 | arr_t = 20.81 | l = 3.51
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 26.51 serving:Job 4 | arr_t = 17.03 | l = 6.55
# Server is idle at 26.51
# 26.72 IO request: Job 7 | inter-arr_t = 26.72 | l = 4.51
# 27.27 IO request: Job 4 | inter-arr_t = 27.27 | l = 1.41
# 28.22 arrive: Job 10 | inter-arr_t = 5.33 | l = 17.85
# 28.22 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           1.79
# Server waken up and works at 28.22
# Number of jobs in the sys: 5
# Queued 1:
# Job 10 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 7 | Job 4 |
#
# Enter handle 1
# 28.22 Job 10 first response time: 0.00
# Queued 1:
#
#
# 28.22 serving:Job 10 | arr_t = 28.22 | l = 17.85
# Server is idle at 28.22
# 31.36: IO finished, Job 1 returns back to queue 1.
# 31.36: Job 7 is implementing IO.
# Server waken up and works at 32.22
# Number of jobs in the sys: 5
# Queued 1:
# Job 1 |
#
# Queued 2:
#
#
# Queued 3:
# Job 6 |
#
# IO queue:
# Job 4 |
#
# Enter handle 1
# Queued 1:
#
#
# 32.22 serving:Job 1 | arr_t = 2.64 | l = 2.84
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 6 |
#
# IO queue:
# Job 4 |
#
# Enter handle 3
# Queued 3:
#
#
# 32.22 serving:Job 6 | arr_t = 20.22 | l = 3.89
# Server is idle at 32.22
# Server waken up and works at 32.22
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 10 |
#
# Queued 3:
#
#
# IO queue:
# Job 4 |
#
# Enter handle 2
# Queued 2:
#
#
# 32.22 serving:Job 10 | arr_t = 28.22 | l = 13.85
# Server is idle at 32.22
# 32.24 IO request: Job 1 | inter-arr_t = 32.24 | l = 0.11
# 35.51 arrive: Job 11 | inter-arr_t = 7.29 | l = 0.12
# 35.51 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           7.29
# Server waken up and works at 35.51
# Number of jobs in the sys: 6
# Queued 1:
# Job 11 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 4 | Job 1 |
#
# Enter handle 1
# 35.51 Job 11 first response time: 0.00
# Queued 1:
#
#
# 35.51 serving:Job 11 | arr_t = 35.51 | l = 0.12
# Server is idle at 35.51
# Job 11: Finish at 35.63, trnd_t = 0.12, wait_t = -0.00
# 35.63 Number of jobs in the system at the time a job finished: 5
# 35.87: IO finished, Job 7 returns back to queue 1.
# 35.87: Job 4 is implementing IO.
# Job 6: Finish at 36.11, trnd_t = 15.89, wait_t = -0.00
# 36.11 Number of jobs in the system at the time a job finished: 4
# 36.49 arrive: Job 12 | inter-arr_t = 0.97 | l = 10.26
# 36.49 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           0.38
# Server waken up and works at 36.49
# Number of jobs in the sys: 5
# Queued 1:
# Job 7 | Job 12 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 1 |
#
# Enter handle 1
# Queued 1:
# Job 12 |
#
# 36.49 serving:Job 7 | arr_t = 20.81 | l = 3.31
# Number of jobs in the sys: 5
# Queued 1:
# Job 12 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 1 |
#
# Enter handle 1
# 36.49 Job 12 first response time: 0.00
# Queued 1:
#
#
# 36.49 serving:Job 12 | arr_t = 36.49 | l = 10.26
# Server is idle at 36.49
# 37.28: IO finished, Job 4 returns back to queue 2.
# 37.28: Job 1 is implementing IO.
# 37.29 IO request: Job 12 | inter-arr_t = 37.29 | l = 3.44
# 37.39: IO finished, Job 1 returns back to queue 1.
# 37.39: Job 12 is implementing IO.
# 38.25 IO request: Job 7 | inter-arr_t = 38.25 | l = 0.98
# 38.54 arrive: Job 13 | inter-arr_t = 2.05 | l = 6.98
# 38.54 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           2.05
# Server waken up and works at 38.54
# Number of jobs in the sys: 6
# Queued 1:
# Job 1 | Job 13 |
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# IO queue:
# Job 7 |
#
# Enter handle 1
# Queued 1:
# Job 13 |
#
# 38.54 serving:Job 1 | arr_t = 2.64 | l = 2.82
# Number of jobs in the sys: 6
# Queued 1:
# Job 13 |
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# IO queue:
# Job 7 |
#
# Enter handle 1
# 38.54 Job 13 first response time: 0.00
# Queued 1:
#
#
# 38.54 serving:Job 13 | arr_t = 38.54 | l = 6.98
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# IO queue:
# Job 7 |
#
# 38.60 IO request: Job 1 | inter-arr_t = 38.60 | l = 0.47
# Enter handle 2
# Queued 2:
#
#
# 38.60 serving:Job 4 | arr_t = 17.03 | l = 5.79
# Server is idle at 38.60
# 39.73 IO request: Job 4 | inter-arr_t = 39.73 | l = 0.11
# Server waken up and works at 40.22
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
# Job 7 | Job 1 | Job 4 |
#
# Enter handle 3
# Queued 3:
#
#
# 40.22 serving:Job 10 | arr_t = 28.22 | l = 5.85
# Server is idle at 40.22
# 40.83: IO finished, Job 12 returns back to queue 1.
# 40.83: Job 7 is implementing IO.
# 41.81: IO finished, Job 7 returns back to queue 1.
# 41.81: Job 1 is implementing IO.
# 42.28: IO finished, Job 1 returns back to queue 1.
# 42.28: Job 4 is implementing IO.
# 42.39: IO finished, Job 4 returns back to queue 2.
# Server waken up and works at 42.54
# Number of jobs in the sys: 6
# Queued 1:
# Job 12 | Job 7 | Job 1 |
#
# Queued 2:
# Job 4 | Job 13 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 7 | Job 1 |
#
# 42.54 serving:Job 12 | arr_t = 36.49 | l = 9.45
# Number of jobs in the sys: 6
# Queued 1:
# Job 7 | Job 1 |
#
# Queued 2:
# Job 4 | Job 13 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 1 |
#
# 42.54 serving:Job 7 | arr_t = 20.81 | l = 1.54
# Number of jobs in the sys: 6
# Queued 1:
# Job 1 |
#
# Queued 2:
# Job 4 | Job 13 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 10 is preempted at 42.54. The remaining allotment is 3.53
# Enter handle 1
# Queued 1:
#
#
# 42.54 serving:Job 1 | arr_t = 2.64 | l = 2.77
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 4 | Job 13 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 42.98 IO request: Job 12 | inter-arr_t = 42.98 | l = 2.48
# IO request at 42.98
# 42.98: Job 12 is implementing IO.
# Enter handle 2
# Queued 2:
# Job 13 |
#
# 42.98 serving:Job 4 | arr_t = 17.03 | l = 4.65
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 13 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 43.35 IO request: Job 7 | inter-arr_t = 43.35 | l = 0.10
# Enter handle 2
# Queued 2:
#
#
# 43.35 serving:Job 13 | arr_t = 38.54 | l = 2.98
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
# Job 7 |
#
# 43.59 arrive: Job 14 | inter-arr_t = 5.04 | l = 16.17
# 43.59 Number of job in the system is sampled at arrival:  6
# Time elapsed form last sample:           5.04
# Enter handle 3
# Queued 3:
#
#
# 44.29 serving:Job 10 | arr_t = 28.22 | l = 3.53
# Number of jobs in the sys: 7
# Queued 1:
# Job 14 |
#
# Queued 2:
# Job 1 |
#
# Queued 3:
#
#
# IO queue:
# Job 7 |
#
# Queued 3:
#
#
# Job 10 is preempted at 44.29. The remaining allotment is 3.53
# Enter handle 1
# 44.29 Job 14 first response time: 0.71
# Queued 1:
#
#
# 44.29 serving:Job 14 | arr_t = 43.59 | l = 16.17
# Number of jobs in the sys: 7
# Queued 1:
#
#
# Queued 2:
# Job 1 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
# Job 7 |
#
# 45.46: IO finished, Job 12 returns back to queue 1.
# 45.46: Job 7 is implementing IO.
# 45.55: IO finished, Job 7 returns back to queue 1.
# Job 13: Finish at 46.33, trnd_t = 7.79, wait_t = 0.81
# 46.33 Number of jobs in the system at the time a job finished: 6
# Enter handle 2
# Queued 2:
#
#
# 46.33 serving:Job 1 | arr_t = 2.64 | l = 1.02
# Number of jobs in the sys: 6
# Queued 1:
# Job 12 | Job 7 |
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 1 is preempted at 46.33. The remaining allotment is 1.02
# Enter handle 1
# Queued 1:
# Job 7 |
#
# 46.33 serving:Job 12 | arr_t = 36.49 | l = 9.02
# Number of jobs in the sys: 6
# Queued 1:
# Job 7 |
#
# Queued 2:
# Job 1 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# Queued 2:
# Job 1 |
#
# Job 4 is preempted at 46.33. The remaining allotment is 1.30
# Enter handle 1
# Queued 1:
#
#
# 46.33 serving:Job 7 | arr_t = 20.81 | l = 0.73
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 1 | Job 4 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 46.68 IO request: Job 7 | inter-arr_t = 46.68 | l = 0.40
# IO request at 46.68
# 46.68: Job 7 is implementing IO.
# Enter handle 2
# Queued 2:
# Job 4 |
#
# 46.68 serving:Job 1 | arr_t = 2.64 | l = 1.02
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 4 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 47.08: IO finished, Job 7 returns back to queue 1.
# 47.45 IO request: Job 1 | inter-arr_t = 47.45 | l = 1.18
# IO request at 47.45
# 47.45: Job 1 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 47.45 serving:Job 4 | arr_t = 17.03 | l = 1.30
# Number of jobs in the sys: 6
# Queued 1:
# Job 7 |
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 4 is preempted at 47.45. The remaining allotment is 1.30
# Enter handle 1
# Queued 1:
#
#
# 47.45 serving:Job 7 | arr_t = 20.81 | l = 0.38
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 4 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# Job 7: Finish at 47.83, trnd_t = 27.01, wait_t = 13.77
# 47.83 Number of jobs in the system at the time a job finished: 5
# Enter handle 2
# Queued 2:
#
#
# 47.83 serving:Job 4 | arr_t = 17.03 | l = 1.30
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 48.29 serving:Job 10 | arr_t = 28.22 | l = 3.53
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 14 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 10 is preempted at 48.29. The remaining allotment is 3.53
# Enter handle 2
# Queued 2:
#
#
# 48.29 serving:Job 14 | arr_t = 43.59 | l = 12.17
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 48.63: IO finished, Job 1 returns back to queue 2.
# Enter handle 3
# Queued 3:
#
#
# 49.09 serving:Job 10 | arr_t = 28.22 | l = 3.53
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 1 | Job 12 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 10 is preempted at 49.09. The remaining allotment is 3.53
# Enter handle 2
# Queued 2:
# Job 12 |
#
# 49.09 serving:Job 1 | arr_t = 2.64 | l = 0.25
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 12 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 49.09 IO request: Job 1 | inter-arr_t = 49.09 | l = 0.96
# IO request at 49.09
# 49.09: Job 1 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 49.09 serving:Job 12 | arr_t = 36.49 | l = 6.26
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 49.12 arrive: Job 15 | inter-arr_t = 5.53 | l = 0.98
# 49.12 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           1.29
# 49.12 IO request: Job 12 | inter-arr_t = 49.12 | l = 0.09
# Enter handle 3
# Queued 3:
#
#
# 49.12 serving:Job 10 | arr_t = 28.22 | l = 3.53
# Number of jobs in the sys: 6
# Queued 1:
# Job 15 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 12 |
#
# Queued 3:
#
#
# Job 10 is preempted at 49.12. The remaining allotment is 3.53
# Enter handle 1
# 49.12 Job 15 first response time: 0.00
# Queued 1:
#
#
# 49.12 serving:Job 15 | arr_t = 49.12 | l = 0.98
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
# Job 12 |
#
# Job 4: Finish at 49.13, trnd_t = 32.10, wait_t = 18.97
# 49.13 Number of jobs in the system at the time a job finished: 5
# Enter handle 3
# Queued 3:
#
#
# 49.13 serving:Job 10 | arr_t = 28.22 | l = 3.53
# Server is idle at 49.13
# 50.04 arrive: Job 16 | inter-arr_t = 0.92 | l = 3.12
# 50.04 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           0.91
# Server waken up and works at 50.04
# Number of jobs in the sys: 6
# Queued 1:
# Job 16 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
# Job 12 |
#
# Queued 3:
#
#
# Job 10 is preempted at 50.04. The remaining allotment is 2.62
# Enter handle 1
# 50.04 Job 16 first response time: 0.00
# Queued 1:
#
#
# 50.04 serving:Job 16 | arr_t = 50.04 | l = 3.12
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
# Job 12 |
#
# 50.06: IO finished, Job 1 returns back to queue 2.
# 50.06: Job 12 is implementing IO.
# Job 15: Finish at 50.10, trnd_t = 0.98, wait_t = 0.00
# 50.10 Number of jobs in the system at the time a job finished: 5
# Enter handle 3
# Queued 3:
#
#
# 50.10 serving:Job 10 | arr_t = 28.22 | l = 2.62
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 1 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 10 is preempted at 50.10. The remaining allotment is 2.62
# Enter handle 2
# Queued 2:
#
#
# 50.10 serving:Job 1 | arr_t = 2.64 | l = 0.25
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 50.11 arrive: Job 17 | inter-arr_t = 0.06 | l = 25.94
# 50.11 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           0.01
# 50.14: IO finished, Job 12 returns back to queue 2.
# Job 1: Finish at 50.34, trnd_t = 47.70, wait_t = 27.51
# 50.34 Number of jobs in the system at the time a job finished: 5
# Enter handle 3
# Queued 3:
#
#
# 50.34 serving:Job 10 | arr_t = 28.22 | l = 2.62
# Number of jobs in the sys: 5
# Queued 1:
# Job 17 |
#
# Queued 2:
# Job 12 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 10 is preempted at 50.34. The remaining allotment is 2.62
# Enter handle 1
# 50.34 Job 17 first response time: 0.24
# Queued 1:
#
#
# 50.34 serving:Job 17 | arr_t = 50.11 | l = 25.94
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 12 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 51.32 IO request: Job 16 | inter-arr_t = 51.32 | l = 1.37
# IO request at 51.32
# 51.32: Job 16 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 51.32 serving:Job 12 | arr_t = 36.49 | l = 6.23
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 52.37 IO request: Job 12 | inter-arr_t = 52.37 | l = 0.45
# Enter handle 3
# Queued 3:
#
#
# 52.37 serving:Job 10 | arr_t = 28.22 | l = 2.62
# Server is idle at 52.37
# 52.69: IO finished, Job 16 returns back to queue 1.
# 52.69: Job 12 is implementing IO.
# 53.15: IO finished, Job 12 returns back to queue 2.
# Server waken up and works at 54.34
# Number of jobs in the sys: 5
# Queued 1:
# Job 16 |
#
# Queued 2:
# Job 12 | Job 17 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
#
#
# 54.34 serving:Job 16 | arr_t = 50.04 | l = 1.84
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 12 | Job 17 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 10 is preempted at 54.34. The remaining allotment is 0.64
# Enter handle 2
# Queued 2:
# Job 17 |
#
# 54.34 serving:Job 12 | arr_t = 36.49 | l = 5.19
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 17 |
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 54.95 IO request: Job 16 | inter-arr_t = 54.95 | l = 1.13
# IO request at 54.95
# 54.95: Job 16 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 54.95 serving:Job 17 | arr_t = 50.11 | l = 21.94
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 10 |
#
# IO queue:
#
#
# 55.21 IO request: Job 12 | inter-arr_t = 55.21 | l = 0.91
# Enter handle 3
# Queued 3:
#
#
# 55.21 serving:Job 10 | arr_t = 28.22 | l = 0.64
# Server is idle at 55.21
# Job 10: Finish at 55.85, trnd_t = 27.63, wait_t = 9.77
# 55.85 Number of jobs in the system at the time a job finished: 4
# 56.07: IO finished, Job 16 returns back to queue 1.
# 56.07: Job 12 is implementing IO.
# Server waken up and works at 56.29
# Number of jobs in the sys: 4
# Queued 1:
# Job 16 |
#
# Queued 2:
#
#
# Queued 3:
# Job 14 |
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
#
#
# 56.29 serving:Job 16 | arr_t = 50.04 | l = 1.24
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 14 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 56.29 serving:Job 14 | arr_t = 43.59 | l = 4.17
# Server is idle at 56.29
# 56.98: IO finished, Job 12 returns back to queue 2.
# Job 16: Finish at 57.53, trnd_t = 7.49, wait_t = 1.87
# 57.53 Number of jobs in the system at the time a job finished: 3
# Job 14: Finish at 60.47, trnd_t = 16.88, wait_t = 0.71
# 60.47 Number of jobs in the system at the time a job finished: 2
# 60.74 arrive: Job 18 | inter-arr_t = 10.64 | l = 9.76
# 60.74 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           0.27
# Server waken up and works at 60.74
# Number of jobs in the sys: 3
# Queued 1:
# Job 18 |
#
# Queued 2:
# Job 12 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 60.74 Job 18 first response time: 0.00
# Queued 1:
#
#
# 60.74 serving:Job 18 | arr_t = 60.74 | l = 9.76
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 12 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 60.74 serving:Job 12 | arr_t = 36.49 | l = 4.33
# Server is idle at 60.74
# Server waken up and works at 62.95
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 17 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 62.95 serving:Job 17 | arr_t = 50.11 | l = 13.94
# Server is idle at 62.95
# 63.38 arrive: Job 19 | inter-arr_t = 2.64 | l = 10.26
# 63.38 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           2.64
# Server waken up and works at 63.38
# Number of jobs in the sys: 4
# Queued 1:
# Job 19 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 17 is preempted at 63.38. The remaining allotment is 13.51
# Enter handle 1
# 63.38 Job 19 first response time: 0.00
# Queued 1:
#
#
# 63.38 serving:Job 19 | arr_t = 63.38 | l = 10.26
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 17 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 64.74 serving:Job 17 | arr_t = 50.11 | l = 13.51
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 18 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 17 is preempted at 64.74. The remaining allotment is 13.51
# Enter handle 2
# Queued 2:
#
#
# 64.74 serving:Job 18 | arr_t = 60.74 | l = 5.76
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 17 |
#
# IO queue:
#
#
# Job 12: Finish at 65.07, trnd_t = 28.58, wait_t = 10.95
# 65.07 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 65.07 serving:Job 17 | arr_t = 50.11 | l = 13.51
# Server is idle at 65.07
# 67.26 arrive: Job 20 | inter-arr_t = 3.88 | l = 8.37
# 67.26 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           2.19
# Server waken up and works at 67.26
# Number of jobs in the sys: 4
# Queued 1:
# Job 20 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 17 is preempted at 67.26. The remaining allotment is 11.31
# Enter handle 1
# 67.26 Job 20 first response time: 0.00
# Queued 1:
#
#
# 67.26 serving:Job 20 | arr_t = 67.26 | l = 8.37
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 17 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 67.38 serving:Job 17 | arr_t = 50.11 | l = 11.31
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 19 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 17 is preempted at 67.38. The remaining allotment is 11.31
# Enter handle 2
# Queued 2:
#
#
# 67.38 serving:Job 19 | arr_t = 63.38 | l = 6.26
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 17 |
#
# IO queue:
#
#
# 69.52 arrive: Job 21 | inter-arr_t = 2.25 | l = 22.32
# 69.52 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           2.25
# Job 18: Finish at 70.50, trnd_t = 9.76, wait_t = 0.00
# 70.50 Number of jobs in the system at the time a job finished: 4
# Enter handle 3
# Queued 3:
#
#
# 70.50 serving:Job 17 | arr_t = 50.11 | l = 11.31
# Number of jobs in the sys: 4
# Queued 1:
# Job 21 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 17 is preempted at 70.50. The remaining allotment is 11.31
# Enter handle 1
# 70.50 Job 21 first response time: 0.99
# Queued 1:
#
#
# 70.50 serving:Job 21 | arr_t = 69.52 | l = 22.32
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 17 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 71.26 serving:Job 17 | arr_t = 50.11 | l = 11.31
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 20 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 17 is preempted at 71.26. The remaining allotment is 11.31
# Enter handle 2
# Queued 2:
#
#
# 71.26 serving:Job 20 | arr_t = 67.26 | l = 4.37
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 17 |
#
# IO queue:
#
#
# Job 19: Finish at 73.65, trnd_t = 10.26, wait_t = 0.00
# 73.65 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 73.65 serving:Job 17 | arr_t = 50.11 | l = 11.31
# Server is idle at 73.65
# Server waken up and works at 74.50
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 21 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 74.50 serving:Job 21 | arr_t = 69.52 | l = 18.32
# Server is idle at 74.50
# Job 20: Finish at 75.63, trnd_t = 8.37, wait_t = 0.00
# 75.63 Number of jobs in the system at the time a job finished: 2
# 79.80 arrive: Job 22 | inter-arr_t = 10.29 | l = 5.79
# 79.80 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           4.17
# Server waken up and works at 79.80
# Number of jobs in the sys: 3
# Queued 1:
# Job 22 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 79.80 Job 22 first response time: 0.00
# Queued 1:
#
#
# 79.80 serving:Job 22 | arr_t = 79.80 | l = 5.79
# Server is idle at 79.80
# Server waken up and works at 82.50
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 21 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 82.50 serving:Job 21 | arr_t = 69.52 | l = 10.32
# Server is idle at 82.50
# Server waken up and works at 83.80
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 22 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 83.80 serving:Job 22 | arr_t = 79.80 | l = 1.79
# Server is idle at 83.80
# 84.87 arrive: Job 23 | inter-arr_t = 5.07 | l = 5.12
# 84.87 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           5.07
# Server waken up and works at 84.87
# Number of jobs in the sys: 4
# Queued 1:
# Job 23 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 21 is preempted at 84.87. The remaining allotment is 7.95
# Enter handle 1
# 84.87 Job 23 first response time: 0.00
# Queued 1:
#
#
# 84.87 serving:Job 23 | arr_t = 84.87 | l = 5.12
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 21 |
#
# IO queue:
#
#
# Job 17: Finish at 84.96, trnd_t = 34.85, wait_t = 8.91
# 84.96 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 84.96 serving:Job 21 | arr_t = 69.52 | l = 7.95
# Server is idle at 84.96
# Job 22: Finish at 85.60, trnd_t = 5.79, wait_t = -0.00
# 85.60 Number of jobs in the system at the time a job finished: 2
# Server waken up and works at 88.87
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 23 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 88.87 serving:Job 23 | arr_t = 84.87 | l = 1.12
# Server is idle at 88.87
# Job 23: Finish at 90.00, trnd_t = 5.12, wait_t = -0.00
# 90.00 Number of jobs in the system at the time a job finished: 1
# 91.90 arrive: Job 24 | inter-arr_t = 7.03 | l = 11.30
# 91.90 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           1.91
# Server waken up and works at 91.90
# Number of jobs in the sys: 2
# Queued 1:
# Job 24 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 91.90 Job 24 first response time: 0.00
# Queued 1:
#
#
# 91.90 serving:Job 24 | arr_t = 91.90 | l = 11.30
# Server is idle at 91.90
# Job 21: Finish at 92.91, trnd_t = 23.39, wait_t = 1.07
# 92.91 Number of jobs in the system at the time a job finished: 1
# Server waken up and works at 95.90
# Number of jobs in the sys: 1
# Queued 1:
#
#
# Queued 2:
# Job 24 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 95.90 serving:Job 24 | arr_t = 91.90 | l = 7.30
# Server is idle at 95.90
# TIME OUT !!!
# Number of jobs in the sys: 1
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
#
#
# Job 24: Finish at 103.21, trnd_t = 11.30, wait_t = 0.00
# 103.21 Number of jobs in the system at the time a job finished: 0
# 104.15 arrive: Job 25 | inter-arr_t = 12.25 | l = 13.81
# 104.15 Number of job in the system is sampled at arrival:  0
# Time elapsed form last sample:           0.94
# Server waken up and works at 104.15
# Number of jobs in the sys: 1
# Queued 1:
# Job 25 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 104.15 Job 25 first response time: 0.00
# Queued 1:
#
#
# 104.15 serving:Job 25 | arr_t = 104.15 | l = 13.81
# Server is idle at 104.15
# Server waken up and works at 108.15
# Number of jobs in the sys: 1
# Queued 1:
#
#
# Queued 2:
# Job 25 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 108.15 serving:Job 25 | arr_t = 104.15 | l = 9.81
# Server is idle at 108.15
# 108.98 arrive: Job 26 | inter-arr_t = 4.83 | l = 20.74
# 108.98 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           4.83
# Server waken up and works at 108.98
# Number of jobs in the sys: 2
# Queued 1:
# Job 26 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 108.98 Job 26 first response time: 0.00
# Queued 1:
#
#
# 108.98 serving:Job 26 | arr_t = 108.98 | l = 20.74
# Server is idle at 108.98
# 109.30 arrive: Job 27 | inter-arr_t = 0.32 | l = 9.02
# 109.30 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           0.32
# Server waken up and works at 109.30
# Number of jobs in the sys: 3
# Queued 1:
# Job 27 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 109.30 Job 27 first response time: 0.00
# Queued 1:
#
#
# 109.30 serving:Job 27 | arr_t = 109.30 | l = 9.02
# Server is idle at 109.30
# 110.18 arrive: Job 28 | inter-arr_t = 0.88 | l = 14.79
# 110.18 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           0.88
# Server waken up and works at 110.18
# Number of jobs in the sys: 4
# Queued 1:
# Job 28 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 25 is preempted at 110.18. The remaining allotment is 7.78
# Enter handle 1
# 110.18 Job 28 first response time: 0.00
# Queued 1:
#
#
# 110.18 serving:Job 28 | arr_t = 110.18 | l = 14.79
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 25 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
# Job 26 |
#
# 112.98 serving:Job 25 | arr_t = 104.15 | l = 7.78
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 26 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
# Job 27 |
#
# 113.30 serving:Job 26 | arr_t = 108.98 | l = 16.74
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 27 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
# Job 28 |
#
# 114.18 serving:Job 27 | arr_t = 109.30 | l = 5.02
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 28 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 118.44 arrive: Job 29 | inter-arr_t = 8.26 | l = 0.46
# 118.44 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           8.26
# 118.66 arrive: Job 30 | inter-arr_t = 0.22 | l = 13.81
# 118.66 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           0.22
# Enter handle 2
# Queued 2:
#
#
# 118.95 serving:Job 28 | arr_t = 110.18 | l = 10.79
# Number of jobs in the sys: 6
# Queued 1:
# Job 29 | Job 30 |
#
# Queued 2:
#
#
# Queued 3:
# Job 25 |
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 28 is preempted at 118.95. The remaining allotment is 10.79
# Enter handle 1
# 118.95 Job 29 first response time: 0.51
# Queued 1:
# Job 30 |
#
# 118.95 serving:Job 29 | arr_t = 118.44 | l = 0.46
# Number of jobs in the sys: 6
# Queued 1:
# Job 30 |
#
# Queued 2:
# Job 28 |
#
# Queued 3:
# Job 25 |
#
# IO queue:
#
#
# Queued 2:
# Job 28 |
#
# Job 27 is preempted at 118.95. The remaining allotment is 0.25
# Enter handle 1
# 118.95 Job 30 first response time: 0.29
# Queued 1:
#
#
# 118.95 serving:Job 30 | arr_t = 118.66 | l = 13.81
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 28 | Job 27 |
#
# Queued 3:
# Job 25 |
#
# IO queue:
#
#
# Job 29: Finish at 119.41, trnd_t = 0.97, wait_t = 0.51
# 119.41 Number of jobs in the system at the time a job finished: 5
# Enter handle 2
# Queued 2:
# Job 27 |
#
# 119.41 serving:Job 28 | arr_t = 110.18 | l = 10.79
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 27 |
#
# Queued 3:
# Job 25 |
#
# IO queue:
#
#
# 121.18 IO request: Job 30 | inter-arr_t = 121.18 | l = 1.19
# IO request at 121.18
# 121.18: Job 30 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 121.18 serving:Job 27 | arr_t = 109.30 | l = 0.25
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 25 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
# Job 26 |
#
# 121.30 serving:Job 25 | arr_t = 104.15 | l = 1.81
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 26 |
#
# IO queue:
#
#
# Job 27: Finish at 121.43, trnd_t = 12.12, wait_t = 3.11
# 121.43 Number of jobs in the system at the time a job finished: 4
# Enter handle 3
# Queued 3:
#
#
# 121.43 serving:Job 26 | arr_t = 108.98 | l = 8.74
# Server is idle at 121.43
# 122.37: IO finished, Job 30 returns back to queue 1.
# Job 25: Finish at 123.12, trnd_t = 18.97, wait_t = 5.15
# 123.12 Number of jobs in the system at the time a job finished: 3
# 125.16 arrive: Job 31 | inter-arr_t = 6.50 | l = 3.21
# 125.16 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           2.04
# Server waken up and works at 125.16
# Number of jobs in the sys: 4
# Queued 1:
# Job 30 | Job 31 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 31 |
#
# 125.16 serving:Job 30 | arr_t = 118.66 | l = 11.58
# Number of jobs in the sys: 4
# Queued 1:
# Job 31 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 26 is preempted at 125.16. The remaining allotment is 5.00
# Enter handle 1
# 125.16 Job 31 first response time: 0.00
# Queued 1:
#
#
# 125.16 serving:Job 31 | arr_t = 125.16 | l = 3.21
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 26 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 126.93 serving:Job 26 | arr_t = 108.98 | l = 5.00
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 30 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 26 is preempted at 126.93. The remaining allotment is 5.00
# Enter handle 2
# Queued 2:
#
#
# 126.93 serving:Job 30 | arr_t = 118.66 | l = 9.81
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 26 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
# Job 28 |
#
# 127.41 serving:Job 26 | arr_t = 108.98 | l = 5.00
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 28 |
#
# IO queue:
#
#
# Job 31: Finish at 128.37, trnd_t = 3.21, wait_t = 0.00
# 128.37 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 128.37 serving:Job 28 | arr_t = 110.18 | l = 2.79
# Server is idle at 128.37
# 128.54 IO request: Job 30 | inter-arr_t = 128.54 | l = 3.96
# IO request at 128.54
# 128.54: Job 30 is implementing IO.
# 129.52 arrive: Job 32 | inter-arr_t = 4.36 | l = 13.11
# 129.52 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           1.15
# Server waken up and works at 129.52
# Number of jobs in the sys: 4
# Queued 1:
# Job 32 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 129.52 Job 32 first response time: 0.00
# Queued 1:
#
#
# 129.52 serving:Job 32 | arr_t = 129.52 | l = 13.11
# Server is idle at 129.52
# Job 28: Finish at 131.16, trnd_t = 20.97, wait_t = 6.19
# 131.16 Number of jobs in the system at the time a job finished: 3
# Job 26: Finish at 132.41, trnd_t = 23.43, wait_t = 2.70
# 132.41 Number of jobs in the system at the time a job finished: 2
# 132.50: IO finished, Job 30 returns back to queue 2.
# Server waken up and works at 133.52
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 30 | Job 32 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
# Job 32 |
#
# 133.52 serving:Job 30 | arr_t = 118.66 | l = 8.20
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 32 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 133.52 serving:Job 32 | arr_t = 129.52 | l = 9.11
# Server is idle at 133.52
# 135.78 arrive: Job 33 | inter-arr_t = 6.26 | l = 8.47
# 135.78 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           3.37
# Server waken up and works at 135.78
# Number of jobs in the sys: 3
# Queued 1:
# Job 33 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 135.78 Job 33 first response time: 0.00
# Queued 1:
#
#
# 135.78 serving:Job 33 | arr_t = 135.78 | l = 8.47
# Server is idle at 135.78
# 138.41 IO request: Job 30 | inter-arr_t = 138.41 | l = 11.36
# IO request at 138.41
# 138.41: Job 30 is implementing IO.
# Server waken up and works at 139.78
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 33 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 139.78 serving:Job 33 | arr_t = 135.78 | l = 4.47
# Server is idle at 139.78
# Server waken up and works at 141.52
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 32 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 141.52 serving:Job 32 | arr_t = 129.52 | l = 1.11
# Server is idle at 141.52
# Job 32: Finish at 142.63, trnd_t = 13.11, wait_t = 0.00
# 142.63 Number of jobs in the system at the time a job finished: 2
# Job 33: Finish at 144.25, trnd_t = 8.47, wait_t = -0.00
# 144.25 Number of jobs in the system at the time a job finished: 1
# 149.78: IO finished, Job 30 returns back to queue 2.
# 151.81 arrive: Job 34 | inter-arr_t = 16.03 | l = 4.68
# 151.81 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           7.56
# Server waken up and works at 151.81
# Number of jobs in the sys: 2
# Queued 1:
# Job 34 |
#
# Queued 2:
# Job 30 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 151.81 Job 34 first response time: 0.00
# Queued 1:
#
#
# 151.81 serving:Job 34 | arr_t = 151.81 | l = 4.68
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 30 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 151.81 serving:Job 30 | arr_t = 118.66 | l = 3.31
# Server is idle at 151.81
# Server waken up and works at 153.31
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 30 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 153.31 serving:Job 30 | arr_t = 118.66 | l = 1.81
# Server is idle at 153.31
# 153.71 IO request: Job 30 | inter-arr_t = 153.71 | l = 1.40
# IO request at 153.71
# 153.71: Job 30 is implementing IO.
# 154.67 arrive: Job 35 | inter-arr_t = 2.86 | l = 6.15
# 154.67 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           2.86
# Server waken up and works at 154.67
# Number of jobs in the sys: 3
# Queued 1:
# Job 35 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 154.67 Job 35 first response time: 0.00
# Queued 1:
#
#
# 154.67 serving:Job 35 | arr_t = 154.67 | l = 6.15
# Server is idle at 154.67
# 155.11: IO finished, Job 30 returns back to queue 3.
# 155.22 arrive: Job 36 | inter-arr_t = 0.55 | l = 2.22
# 155.22 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           0.55
# Server waken up and works at 155.22
# Number of jobs in the sys: 4
# Queued 1:
# Job 36 |
#
# Queued 2:
#
#
# Queued 3:
# Job 30 |
#
# IO queue:
#
#
# Enter handle 1
# 155.22 Job 36 first response time: 0.00
# Queued 1:
#
#
# 155.22 serving:Job 36 | arr_t = 155.22 | l = 2.22
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 30 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 155.81 serving:Job 30 | arr_t = 118.66 | l = 1.41
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 34 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 30 is preempted at 155.81. The remaining allotment is 1.41
# Enter handle 2
# Queued 2:
#
#
# 155.81 serving:Job 34 | arr_t = 151.81 | l = 0.68
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 30 |
#
# IO queue:
#
#
# 156.41 arrive: Job 37 | inter-arr_t = 1.19 | l = 10.60
# 156.41 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           1.19
# Job 34: Finish at 156.49, trnd_t = 4.68, wait_t = -0.00
# 156.49 Number of jobs in the system at the time a job finished: 4
# Enter handle 3
# Queued 3:
#
#
# 156.49 serving:Job 30 | arr_t = 118.66 | l = 1.41
# Number of jobs in the sys: 4
# Queued 1:
# Job 37 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 30 is preempted at 156.49. The remaining allotment is 1.41
# Enter handle 1
# 156.49 Job 37 first response time: 0.08
# Queued 1:
#
#
# 156.49 serving:Job 37 | arr_t = 156.41 | l = 10.60
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 30 |
#
# IO queue:
#
#
# Job 36: Finish at 157.44, trnd_t = 2.22, wait_t = -0.00
# 157.44 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 157.44 serving:Job 30 | arr_t = 118.66 | l = 1.41
# Server is idle at 157.44
# 157.98 IO request: Job 30 | inter-arr_t = 157.98 | l = 1.63
# IO request at 157.98
# 157.98: Job 30 is implementing IO.
# Server waken up and works at 158.67
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 35 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 158.67 serving:Job 35 | arr_t = 154.67 | l = 2.15
# Server is idle at 158.67
# 159.59 arrive: Job 38 | inter-arr_t = 3.18 | l = 26.60
# 159.59 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           2.14
# Server waken up and works at 159.59
# Number of jobs in the sys: 4
# Queued 1:
# Job 38 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 159.59 Job 38 first response time: 0.00
# Queued 1:
#
#
# 159.59 serving:Job 38 | arr_t = 159.59 | l = 26.60
# Server is idle at 159.59
# 159.61: IO finished, Job 30 returns back to queue 3.
# Server waken up and works at 160.49
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 37 |
#
# Queued 3:
# Job 30 |
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 160.49 serving:Job 37 | arr_t = 156.41 | l = 6.60
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 30 |
#
# IO queue:
#
#
# Job 35: Finish at 160.82, trnd_t = 6.15, wait_t = -0.00
# 160.82 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 160.82 serving:Job 30 | arr_t = 118.66 | l = 0.87
# Server is idle at 160.82
# Job 30: Finish at 161.69, trnd_t = 43.04, wait_t = 9.69
# 161.69 Number of jobs in the system at the time a job finished: 2
# 161.77 arrive: Job 39 | inter-arr_t = 2.18 | l = 1.23
# 161.77 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           0.07
# Server waken up and works at 161.77
# Number of jobs in the sys: 3
# Queued 1:
# Job 39 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 161.77 Job 39 first response time: 0.00
# Queued 1:
#
#
# 161.77 serving:Job 39 | arr_t = 161.77 | l = 1.23
# Server is idle at 161.77
# 162.49 IO request: Job 39 | inter-arr_t = 162.49 | l = 1.25
# IO request at 162.49
# 162.49: Job 39 is implementing IO.
# 162.63 arrive: Job 40 | inter-arr_t = 0.86 | l = 0.43
# 162.63 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           0.86
# Server waken up and works at 162.63
# Number of jobs in the sys: 4
# Queued 1:
# Job 40 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 162.63 Job 40 first response time: 0.00
# Queued 1:
#
#
# 162.63 serving:Job 40 | arr_t = 162.63 | l = 0.43
# Server is idle at 162.63
# Job 40: Finish at 163.06, trnd_t = 0.43, wait_t = 0.00
# 163.06 Number of jobs in the system at the time a job finished: 3
# Server waken up and works at 163.59
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 38 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 163.59 serving:Job 38 | arr_t = 159.59 | l = 22.60
# Server is idle at 163.59
# 163.74: IO finished, Job 39 returns back to queue 1.
# 166.52 arrive: Job 41 | inter-arr_t = 3.89 | l = 6.22
# 166.52 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           3.46
# Server waken up and works at 166.52
# Number of jobs in the sys: 4
# Queued 1:
# Job 39 | Job 41 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 41 |
#
# 166.52 serving:Job 39 | arr_t = 161.77 | l = 0.50
# Number of jobs in the sys: 4
# Queued 1:
# Job 41 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 38 is preempted at 166.52. The remaining allotment is 19.67
# Enter handle 1
# 166.52 Job 41 first response time: 0.00
# Queued 1:
#
#
# 166.52 serving:Job 41 | arr_t = 166.52 | l = 6.22
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 38 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 166.84 IO request: Job 39 | inter-arr_t = 166.84 | l = 0.31
# IO request at 166.84
# 166.84: Job 39 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 166.84 serving:Job 38 | arr_t = 159.59 | l = 19.67
# Server is idle at 166.84
# Job 37: Finish at 167.09, trnd_t = 10.67, wait_t = 0.08
# 167.09 Number of jobs in the system at the time a job finished: 3
# 167.14: IO finished, Job 39 returns back to queue 1.
# Server waken up and works at 170.52
# Number of jobs in the sys: 3
# Queued 1:
# Job 39 |
#
# Queued 2:
# Job 41 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
#
#
# 170.52 serving:Job 39 | arr_t = 161.77 | l = 0.18
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 41 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 170.52 serving:Job 41 | arr_t = 166.52 | l = 2.22
# Server is idle at 170.52
# Job 39: Finish at 170.70, trnd_t = 8.93, wait_t = 6.15
# 170.70 Number of jobs in the system at the time a job finished: 2
# Server waken up and works at 171.91
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 38 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 171.91 serving:Job 38 | arr_t = 159.59 | l = 14.60
# Server is idle at 171.91
# Job 41: Finish at 172.74, trnd_t = 6.22, wait_t = -0.00
# 172.74 Number of jobs in the system at the time a job finished: 1
# 178.39 arrive: Job 42 | inter-arr_t = 11.88 | l = 3.30
# 178.39 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           5.65
# Server waken up and works at 178.39
# Number of jobs in the sys: 2
# Queued 1:
# Job 42 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 178.39 Job 42 first response time: 0.00
# Queued 1:
#
#
# 178.39 serving:Job 42 | arr_t = 178.39 | l = 3.30
# Server is idle at 178.39
# Job 42: Finish at 181.69, trnd_t = 3.30, wait_t = 0.00
# 181.69 Number of jobs in the system at the time a job finished: 1
# 183.66 arrive: Job 43 | inter-arr_t = 5.26 | l = 7.32
# 183.66 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           1.97
# Server waken up and works at 183.66
# Number of jobs in the sys: 2
# Queued 1:
# Job 43 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 183.66 Job 43 first response time: 0.00
# Queued 1:
#
#
# 183.66 serving:Job 43 | arr_t = 183.66 | l = 7.32
# Server is idle at 183.66
# 183.89 IO request: Job 43 | inter-arr_t = 183.89 | l = 5.58
# IO request at 183.89
# 183.89: Job 43 is implementing IO.
# Job 38: Finish at 186.51, trnd_t = 26.92, wait_t = 0.32
# ...
#
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 77 is preempted at 327.72. The remaining allotment is 1.52
# Enter handle 1
# 327.72 Job 80 first response time: 0.26
# Queued 1:
#
#
# 327.72 serving:Job 80 | arr_t = 327.47 | l = 26.08
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 77 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 327.79 arrive: Job 81 | inter-arr_t = 0.33 | l = 3.51
# 327.79 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           0.33
# Enter handle 2
# Queued 2:
# Job 78 |
#
# 328.30 serving:Job 77 | arr_t = 323.42 | l = 1.52
# Number of jobs in the sys: 6
# Queued 1:
# Job 81 |
#
# Queued 2:
# Job 78 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
# Job 78 |
#
# Job 77 is preempted at 328.30. The remaining allotment is 1.52
# Enter handle 1
# 328.30 Job 81 first response time: 0.50
# Queued 1:
#
#
# 328.30 serving:Job 81 | arr_t = 327.79 | l = 3.51
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 78 | Job 77 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 328.69: IO finished, Job 55 returns back to queue 1.
# 329.45 arrive: Job 82 | inter-arr_t = 1.66 | l = 30.48
# 329.45 Number of job in the system is sampled at arrival:  6
# Time elapsed form last sample:           1.66
# Enter handle 2
# Queued 2:
# Job 77 | Job 79 |
#
# 330.12 serving:Job 78 | arr_t = 324.30 | l = 7.04
# Number of jobs in the sys: 7
# Queued 1:
# Job 55 | Job 82 |
#
# Queued 2:
# Job 77 | Job 79 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
# Job 77 | Job 79 |
#
# Job 78 is preempted at 330.12. The remaining allotment is 7.04
# Enter handle 1
# Queued 1:
# Job 82 |
#
# 330.12 serving:Job 55 | arr_t = 223.43 | l = 3.11
# Number of jobs in the sys: 7
# Queued 1:
# Job 82 |
#
# Queued 2:
# Job 77 | Job 79 | Job 78 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 331.72 Job 82 first response time: 2.27
# Queued 1:
#
#
# 331.72 serving:Job 82 | arr_t = 329.45 | l = 30.48
# Number of jobs in the sys: 7
# Queued 1:
#
#
# Queued 2:
# Job 77 | Job 79 | Job 78 | Job 80 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Job 81: Finish at 331.81, trnd_t = 4.02, wait_t = 0.50
# 331.81 Number of jobs in the system at the time a job finished: 6
# Enter handle 2
# Queued 2:
# Job 79 | Job 78 | Job 80 |
#
# 331.81 serving:Job 77 | arr_t = 323.42 | l = 1.52
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 79 | Job 78 | Job 80 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 332.12 IO request: Job 82 | inter-arr_t = 332.12 | l = 0.16
# IO request at 332.12
# 332.12: Job 82 is implementing IO.
# Enter handle 2
# Queued 2:
# Job 78 | Job 80 |
#
# 332.12 serving:Job 79 | arr_t = 326.12 | l = 52.21
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 78 | Job 80 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 332.18 IO request: Job 55 | inter-arr_t = 332.18 | l = 1.26
# Enter handle 2
# Queued 2:
# Job 80 |
#
# 332.18 serving:Job 78 | arr_t = 324.30 | l = 7.04
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
# Job 80 |
#
# Queued 3:
#
#
# IO queue:
# Job 55 |
#
# 332.28: IO finished, Job 82 returns back to queue 1.
# 332.28: Job 55 is implementing IO.
# Job 77: Finish at 333.33, trnd_t = 9.91, wait_t = 4.38
# 333.33 Number of jobs in the system at the time a job finished: 5
# Enter handle 2
# Queued 2:
#
#
# 333.33 serving:Job 80 | arr_t = 327.47 | l = 22.08
# Number of jobs in the sys: 5
# Queued 1:
# Job 82 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 80 is preempted at 333.33. The remaining allotment is 22.08
# Enter handle 1
# Queued 1:
#
#
# 333.33 serving:Job 82 | arr_t = 329.45 | l = 30.08
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 80 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 333.54: IO finished, Job 55 returns back to queue 1.
# 335.03 IO request: Job 82 | inter-arr_t = 335.03 | l = 3.94
# IO request at 335.03
# 335.03: Job 82 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 335.03 serving:Job 80 | arr_t = 327.47 | l = 22.08
# Number of jobs in the sys: 5
# Queued 1:
# Job 55 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 80 is preempted at 335.03. The remaining allotment is 22.08
# Enter handle 1
# Queued 1:
#
#
# 335.03 serving:Job 55 | arr_t = 223.43 | l = 1.05
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 80 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Job 55: Finish at 336.08, trnd_t = 112.66, wait_t = 63.88
# 336.08 Number of jobs in the system at the time a job finished: 4
# Enter handle 2
# Queued 2:
#
#
# 336.08 serving:Job 80 | arr_t = 327.47 | l = 22.08
# Server is idle at 336.08
# 336.17 arrive: Job 83 | inter-arr_t = 6.72 | l = 12.55
# 336.17 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           0.09
# Server waken up and works at 336.17
# Number of jobs in the sys: 5
# Queued 1:
# Job 83 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 80 is preempted at 336.17. The remaining allotment is 21.99
# Enter handle 1
# 336.17 Job 83 first response time: 0.00
# Queued 1:
#
#
# 336.17 serving:Job 83 | arr_t = 336.17 | l = 12.55
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 80 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 338.97: IO finished, Job 82 returns back to queue 1.
# Job 78: Finish at 339.22, trnd_t = 14.92, wait_t = 3.89
# 339.22 Number of jobs in the system at the time a job finished: 4
# Enter handle 2
# Queued 2:
#
#
# 339.22 serving:Job 80 | arr_t = 327.47 | l = 21.99
# Number of jobs in the sys: 4
# Queued 1:
# Job 82 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 2:
#
#
# Job 80 is preempted at 339.22. The remaining allotment is 21.99
# Enter handle 1
# Queued 1:
#
#
# 339.22 serving:Job 82 | arr_t = 329.45 | l = 28.38
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 80 |
#
# Queued 3:
#
#
# IO queue:
#
#
# 340.03 IO request: Job 82 | inter-arr_t = 340.03 | l = 4.86
# IO request at 340.03
# 340.03: Job 82 is implementing IO.
# Enter handle 2
# Queued 2:
#
#
# 340.03 serving:Job 80 | arr_t = 327.47 | l = 21.99
# Server is idle at 340.03
# Server waken up and works at 340.12
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 79 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 340.12 serving:Job 79 | arr_t = 326.12 | l = 44.21
# Server is idle at 340.12
# Server waken up and works at 340.17
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 83 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 340.17 serving:Job 83 | arr_t = 336.17 | l = 8.55
# Server is idle at 340.17
# 344.89: IO finished, Job 82 returns back to queue 1.
# Server waken up and works at 347.94
# Number of jobs in the sys: 4
# Queued 1:
# Job 82 |
#
# Queued 2:
#
#
# Queued 3:
# Job 80 |
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
#
#
# 347.94 serving:Job 82 | arr_t = 329.45 | l = 27.57
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 80 |
#
# IO queue:
#
#
# 348.11 IO request: Job 82 | inter-arr_t = 348.11 | l = 0.32
# IO request at 348.11
# 348.11: Job 82 is implementing IO.
# Enter handle 3
# Queued 3:
#
#
# 348.11 serving:Job 80 | arr_t = 327.47 | l = 14.08
# Server is idle at 348.11
# Server waken up and works at 348.17
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 83 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 348.17 serving:Job 83 | arr_t = 336.17 | l = 0.55
# Server is idle at 348.17
# 348.43: IO finished, Job 82 returns back to queue 1.
# Job 83: Finish at 348.72, trnd_t = 12.55, wait_t = -0.00
# 348.72 Number of jobs in the system at the time a job finished: 3
# Job 80: Finish at 362.19, trnd_t = 34.72, wait_t = 8.65
# 362.19 Number of jobs in the system at the time a job finished: 2
# 367.91 arrive: Job 84 | inter-arr_t = 31.74 | l = 7.28
# 367.91 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           5.72
# Server waken up and works at 367.91
# Number of jobs in the sys: 3
# Queued 1:
# Job 82 | Job 84 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# Queued 1:
# Job 84 |
#
# 367.91 serving:Job 82 | arr_t = 329.45 | l = 27.40
# Number of jobs in the sys: 3
# Queued 1:
# Job 84 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 367.91 Job 84 first response time: 0.00
# Queued 1:
#
#
# 367.91 serving:Job 84 | arr_t = 367.91 | l = 7.28
# Server is idle at 367.91
# Server waken up and works at 368.83
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 82 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 368.83 serving:Job 82 | arr_t = 329.45 | l = 26.48
# Server is idle at 368.83
# 368.97 IO request: Job 82 | inter-arr_t = 368.97 | l = 0.20
# IO request at 368.97
# 368.97: Job 82 is implementing IO.
# 369.17: IO finished, Job 82 returns back to queue 2.
# Server waken up and works at 371.91
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 82 | Job 84 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
# Job 84 |
#
# 371.91 serving:Job 82 | arr_t = 329.45 | l = 26.34
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 84 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 371.91 serving:Job 84 | arr_t = 367.91 | l = 3.28
# Server is idle at 371.91
# 372.29 IO request: Job 82 | inter-arr_t = 372.29 | l = 1.93
# IO request at 372.29
# 372.29: Job 82 is implementing IO.
# 373.30 arrive: Job 85 | inter-arr_t = 5.39 | l = 1.91
# 373.30 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           5.39
# Server waken up and works at 373.30
# Number of jobs in the sys: 4
# Queued 1:
# Job 85 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 373.30 Job 85 first response time: 0.00
# Queued 1:
#
#
# 373.30 serving:Job 85 | arr_t = 373.30 | l = 1.91
# Server is idle at 373.30
# 373.36 arrive: Job 86 | inter-arr_t = 0.06 | l = 3.96
# 373.36 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           0.06
# Server waken up and works at 373.36
# Number of jobs in the sys: 5
# Queued 1:
# Job 86 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 79 is preempted at 373.36. The remaining allotment is 10.97
# Enter handle 1
# 373.36 Job 86 first response time: 0.00
# Queued 1:
#
#
# 373.36 serving:Job 86 | arr_t = 373.36 | l = 3.96
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 79 |
#
# IO queue:
#
#
# 374.22: IO finished, Job 82 returns back to queue 2.
# Job 84: Finish at 375.20, trnd_t = 7.28, wait_t = 0.00
# 375.20 Number of jobs in the system at the time a job finished: 4
# Enter handle 3
# Queued 3:
#
#
# 375.20 serving:Job 79 | arr_t = 326.12 | l = 10.97
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 82 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 79 is preempted at 375.20. The remaining allotment is 10.97
# Enter handle 2
# Queued 2:
#
#
# 375.20 serving:Job 82 | arr_t = 329.45 | l = 25.97
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 79 |
#
# IO queue:
#
#
# Job 85: Finish at 375.22, trnd_t = 1.91, wait_t = -0.00
# 375.22 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 375.22 serving:Job 79 | arr_t = 326.12 | l = 10.97
# Server is idle at 375.22
# 376.47 arrive: Job 87 | inter-arr_t = 3.11 | l = 2.64
# 376.47 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           1.25
# Server waken up and works at 376.47
# Number of jobs in the sys: 4
# Queued 1:
# Job 87 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 79 is preempted at 376.47. The remaining allotment is 9.72
# Enter handle 1
# 376.47 Job 87 first response time: 0.00
# Queued 1:
#
#
# 376.47 serving:Job 87 | arr_t = 376.47 | l = 2.64
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 79 |
#
# IO queue:
#
#
# Job 86: Finish at 377.32, trnd_t = 3.96, wait_t = 0.00
# 377.32 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Queued 3:
#
#
# 377.32 serving:Job 79 | arr_t = 326.12 | l = 9.72
# Server is idle at 377.32
# 378.50 arrive: Job 88 | inter-arr_t = 2.03 | l = 22.71
# 378.50 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           1.18
# Server waken up and works at 378.50
# Number of jobs in the sys: 4
# Queued 1:
# Job 88 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 79 is preempted at 378.50. The remaining allotment is 8.54
# Enter handle 1
# 378.50 Job 88 first response time: 0.00
# Queued 1:
#
#
# 378.50 serving:Job 88 | arr_t = 378.50 | l = 22.71
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 79 |
#
# IO queue:
#
#
# 379.01 IO request: Job 82 | inter-arr_t = 379.01 | l = 5.53
# IO request at 379.01
# 379.01: Job 82 is implementing IO.
# Enter handle 3
# Queued 3:
#
#
# 379.01 serving:Job 79 | arr_t = 326.12 | l = 8.54
# Server is idle at 379.01
# Job 87: Finish at 379.11, trnd_t = 2.64, wait_t = -0.00
# 379.11 Number of jobs in the system at the time a job finished: 3
# 381.63 arrive: Job 89 | inter-arr_t = 3.13 | l = 11.16
# 381.63 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           2.52
# Server waken up and works at 381.63
# Number of jobs in the sys: 4
# Queued 1:
# Job 89 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 381.63 Job 89 first response time: 0.00
# Queued 1:
#
#
# 381.63 serving:Job 89 | arr_t = 381.63 | l = 11.16
# Server is idle at 381.63
# Server waken up and works at 382.50
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 88 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 382.50 serving:Job 88 | arr_t = 378.50 | l = 18.71
# Server is idle at 382.50
# 384.54: IO finished, Job 82 returns back to queue 2.
# Server waken up and works at 385.63
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 82 | Job 89 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
# Job 89 |
#
# 385.63 serving:Job 82 | arr_t = 329.45 | l = 22.15
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 89 |
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 79 is preempted at 385.63. The remaining allotment is 1.92
# Enter handle 2
# Queued 2:
#
#
# 385.63 serving:Job 89 | arr_t = 381.63 | l = 7.16
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 79 |
#
# IO queue:
#
#
# 386.19 IO request: Job 82 | inter-arr_t = 386.19 | l = 2.49
# IO request at 386.19
# 386.19: Job 82 is implementing IO.
# Enter handle 3
# Queued 3:
#
#
# 386.19 serving:Job 79 | arr_t = 326.12 | l = 1.92
# Server is idle at 386.19
# Job 79: Finish at 388.11, trnd_t = 61.99, wait_t = 5.77
# 388.11 Number of jobs in the system at the time a job finished: 3
# 388.30 arrive: Job 90 | inter-arr_t = 6.66 | l = 2.24
# 388.30 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           0.19
# Server waken up and works at 388.30
# Number of jobs in the sys: 4
# Queued 1:
# Job 90 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Enter handle 1
# 388.30 Job 90 first response time: 0.00
# Queued 1:
#
#
# 388.30 serving:Job 90 | arr_t = 388.30 | l = 2.24
# Server is idle at 388.30
# 388.68: IO finished, Job 82 returns back to queue 2.
# 390.35 IO request: Job 90 | inter-arr_t = 390.35 | l = 2.31
# IO request at 390.35
# 390.35: Job 90 is implementing IO.
# Server waken up and works at 390.50
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 82 |
#
# Queued 3:
# Job 88 |
#
# IO queue:
#
#
# Enter handle 2
# Queued 2:
#
#
# 390.50 serving:Job 82 | arr_t = 329.45 | l = 21.60
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 88 |
#
# IO queue:
#
#
# Enter handle 3
# Queued 3:
#
#
# 390.50 serving:Job 88 | arr_t = 378.50 | l = 10.71
# Server is idle at 390.50
# 391.36 arrive: Job 91 | inter-arr_t = 3.07 | l = 2.18
# 391.36 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           3.07
# Server waken up and works at 391.36
# Number of jobs in the sys: 5
# Queued 1:
# Job 91 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# IO queue:
#
#
# Queued 3:
#
#
# Job 88 is preempted at 391.36. The remaining allotment is 9.85
# Enter handle 1
# 391.36 Job 91 first response time: 0.00
# Queued 1:
#
#
# 391.36 serving:Job 91 | arr_t = 391.36 | l = 2.18
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 88 |
#
# IO queue:
#
#
# 391.98 IO request: Job 82 | inter-arr_t = 391.98 | l = 0.43
# Enter handle 3
# Queued 3:
#
#
# 391.98 serving:Job 88 | arr_t = 378.50 | l = 9.85
# Server is idle at 391.98
# 392.67: IO finished, Job 90 returns back to queue 1.
# 392.67: Job 82 is implementing IO.
# Job 89: Finish at 392.80, trnd_t = 11.16, wait_t = -0.00
# 392.80 Number of jobs in the system at the time a job finished: 4
# 393.09: IO finished, Job 82 returns back to queue 2.
# Job 91: Finish at 393.55, trnd_t = 2.18, wait_t = 0.00
# 393.55 Number of jobs in the system at the time a job finished: 3
