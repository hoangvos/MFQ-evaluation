# %%
''' ------------------------ '''
''' Dependencies             '''
''' ------------------------ '''
import simpy
import statistics 
import numpy.random as random
from numpy import *
import matplotlib.pyplot as plt
from kneed import DataGenerator, KneeLocator
from pyDOE import *
import pandas as pd

# %%
''' ------------------------ '''
''' Running mode, Only one   '''
''' option should be True    '''
''' ------------------------ '''
#One time simulation for short demonstration
DEMO = False                 
#Multiple simulations to get mean value 
MULTIPLE_SIMULATION = False
#Again, multiple simulations for experiments
EXPERIMENT = True
# Experiment running for the QUANTUM effect
EXPERIMENT_QUANTUM_On_FIRST_RESPONSE = False

# %%
''' ------------------------ '''
''' Experiment list          '''
''' 2 level only              '''
''' ------------------------ '''
lambda_exp = [0.025, 0.05]
mu_exp = [0.1, 0.2]
quantum_exp = [0.3, 3]

# %%
''' ------------------------ '''
''' Parameters               '''
''' ------------------------ '''
MAXSIMTIME = 1000000
LAMBDA = 0.2
MU = 0.1
QUANTUM_QUEUE_1 = 4
QUANTUM_QUEUE_2 = 8
POPULATION = 50000000
SERVICE_DISCIPLINE = 'RR'
LOGGED = False 
VERBOSE = True
NSIM = 30
NUM_CPU = 3

# %%
''' ------------------------ '''
''' DES model                '''
''' ------------------------ '''
# This is for data recording, haven't use anything yet
# may come handy later so I left it there
class Record:
    total_burst = []   # sum of burst times at each step
    total_hist_t = []  # step at which burst total was recorded
    q_size = []        # size of queue at each step
    q_time = []        # step at which queue size was recorded
    times = []
    mean_burst = []
    wait_t = []
    trnd_t = []
    mean_wait = []
    mean_trnd = []
    arrivals = []      # arrival times of jobs
    finish = []        # finish time of jobs
class Job:
    def __init__(self, name, arrtime, duration, remain, allotment, first_response, priority):
        self.priority = priority
        self.name = name
        self.arrtime = arrtime
        self.service_t = duration
        self.remain_t = remain
        self.allotment = allotment
        self.first_response = first_response
        self.wait_t = 0
        self.trnd_t = 0
        self.resp_t = 0
    def __str__(self):
        return '%s at %d, length %d' %(self.name, self.arrtime, self.duration)

def SJF( job ):
    return job.duration

''' 
A server
- env: SimPy environment
- strat: - FIFO: First In First Out
         - SJF : Shortest Job First
         - RR: Round-robin
'''
class Server:
    def __init__(self, env, strat = 'RR'):
        """ Create resources """
        self.cpu = simpy.PreemptiveResource(env, capacity = NUM_CPU)
        """ Create resources """
        """ Event """
        self.trigger_event = simpy.Event(env)
        """ Event """
        self.env = env
        self.strat = strat
        self.queue_1 = []
        self.queue_2 = []
        self.queue_3 = []
        self.jobServing = 0
        self.serversleeping = None
        ''' statistics '''
        self.waitingTime = 0
        self.jobsDone = 0
        self.serviceTime = 0
        self.responseTime = 0
        self.first_responsetime = 0     # accumulating the first response time
        self.turnaroundTime = 0
        self.timeStamp = 0
        self.jobsTotal = 0              # total jobs had been first responsed
        self.jobsInSysCount = []        # record number of current jobs in the system
        self.jobsInSysCount_t = []      # mark down the time when record occurs
        self.numJobsWithTimes = []      # for mean job in system calculation. don't judge the name tho :(
        
        self.job_in_sys_count = []      # try to count the number of job in sys with even length time
        self.job_in_sys_count_avg = []  # number of job in sys * time length
        self.length = []                # list to store the type of length of queue

        ''' register a new server process '''
        env.process(self.serve())
        env.process(self.timeout()) 

    def serve(self):
        while True:
            ''' 
            do nothing, just change server to idle
            and then yield a wait event which takes infinite time
            '''
            if len(self.queue_1) == 0 and len(self.queue_2) == 0 and len(self.queue_3) == 0:
                self.serversleeping = env.process( self.waiting( self.env))
                yield self.serversleeping
            else:
                ''' 
                record the number of job in system:
                number of job in waiting queue (jobs)
                '''
                 yield self.serversleeping
                
                if VERBOSE:
                    print('Number of jobs in the sys: {0:d}' .format(len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing))
                    print('Queued 1: ')
                    for i in range(len(self.queue_1)):
                            print(self.queue_1[i].name, end=" | ")
                    print('\n')
                    print('Queued 2: ')
                    for i in range(len(self.queue_2)):
                            print(self.queue_2[i].name, end=" | ")
                    print('\n')
                    print('Queued 3: ')
                    for i in range(len(self.queue_3)):
                            print(self.queue_3[i].name, end=" | ")
                    print('\n')
                ''' get the first job to be served'''
                if len(self.queue_1) > 0:
                    with self.cpu.request(priority = 1) as req:
                        try:
                            yield req
                            j = self.queue_1.pop(0)
                        except simpy.Interrupt as interrupt:
                            continue 
                    self.env.process(self.handle_queue_1(j))
                    yield 
                    
                elif len(self.queue_2) > 0:
                    with self.cpu.request(priority = 2) as req:
                        try:
                            yield req
                            j = self.queue_2.pop(0)
                        except simpy.Interrupt as interrupt:
                            continue 
                    self.env.process(self.handle_queue_2(j))
                elif len(self.queue_3) > 0:
                    with self.cpu.request(priority = 3) as req:
                        try:
                            yield req
                            j = self.queue_3.pop(0)
                        except simpy.Interrupt as interrupt:
                            continue 
                    self.env.process(self.handle_queue_3(j))
    def handle_queue_1(self, job):
        print("Enter handle 1")
        with self.cpu.request(priority = job.priority) as req:
            try:
                yield req 
            except simpy.Interrupt as interrupt:
                return 0
            try:
                current_time = self.env.now
                self.jobServing += 1
                if LOGGED:
                    qlog.write( '%.4f\t%d\t%d\n' % (self.env.now, 1 if len(self.queue_1)>0 else 0, len(self.queue_1)) )
                if job.first_response:
                    self.jobsTotal += 1
                    current_t = self.env.now
                    self.first_responsetime += (current_t - job.arrtime)
                    job.first_response = 0
                    if VERBOSE:
                        print("{0:.2f} {1:s} first response time: {2:.2f}".format(env.now, job.name, env.now - job.arrtime))
                    """ if the job is stopped (quantum expired)"""
                if job.remain_t > job.allotment:
                    if VERBOSE:
                        print('Queued 1: ')
                        for i in range(len(self.queue_1)):
                            print(self.queue_1[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' \
                            .format(env.now, job.name, job.arrtime, job.remain_t))
                    yield self.env.timeout(job.allotment)
                    job.remain_t = job.remain_t - job.allotment
                    job.allotment = QUANTUM_QUEUE_2 if job.remain_t >= QUANTUM_QUEUE_2 else job.remain_t
                    self.jobServing -= 1
                    self.queue_2.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority + 1))
                    if not self.serversleeping.triggered:
                        self.serversleeping.interrupt( 'Wake up, please.' )
                elif job.remain_t == job.allotment:
                    if VERBOSE:
                        print('Queued 1: ')
                        for i in range(len(self.queue_1)):
                            print(self.queue_1[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}'.format(env.now, job.name, job.arrtime, job.remain_t))
                    yield self.env.timeout(job.remain_t)
                    self.jobServing -= 1
                    ''' for calculating mean of job in system'''
                    ''' right before the job leaves          '''
                    ''' like 2 2 2 2 2 2 1                   '''
                    ''' mark at this   ^                     '''
                    elapse = self.env.now - self.timeStamp
                    queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing + 1
                    self.numJobsWithTimes.append((queueLength)*(elapse))
                    self.jobsInSysCount.append(queueLength)
                    self.jobsInSysCount_t.append(env.now)
                    self.timeStamp = self.env.now
                    finishTime = env.now
                    job.wait_t = finishTime - job.arrtime - job.service_t
                    job.trnd_t = finishTime - job.arrtime
                    self.waitingTime += job.wait_t
                    self.serviceTime += job.service_t
                    self.turnaroundTime += job.trnd_t
                    self.jobsDone += 1
                    if VERBOSE:
                        print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                            .format(finishTime, job.trnd_t, job.wait_t))
                        print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(env.now,queueLength - 1))
            except simpy.Interrupt as interrupt:
                pass_time = env.now - current_time
                if VERBOSE:
                        print('Queued 1: ')
                        for i in range(len(self.queue_1)):
                            print(self.queue_1[i].name, end=" | ")
                        print('\n')
                        print('{0:s} is preempted at {1:.2f}. The remaining allotment is {2:.2f}'.format(job.name, env.now, job.remain_t - pass_time))
                if env.now - current_time == job.allotment: 
                    if job.remain_t > job.allotment:
                        job.remain_t = job.remain_t - job.allotment
                        job.allotment = QUANTUM_QUEUE_2 if job.remain_t >= QUANTUM_QUEUE_2 else job.remain_t
                        self.jobServing -= 1
                        self.queue_2.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority + 1))
                        if not self.serversleeping.triggered:
                            self.serversleeping.interrupt( 'Wake up, please.' )
                    elif job.remain_t == job.allotment:
                        self.jobServing -= 1
                        elapse = self.env.now - self.timeStamp
                        queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing + 1
                        self.numJobsWithTimes.append((queueLength)*(elapse))
                        self.jobsInSysCount.append(queueLength)
                        self.jobsInSysCount_t.append(env.now)
                        self.timeStamp = self.env.now
                        finishTime = env.now
                        job.wait_t = finishTime - job.arrtime - job.service_t
                        job.trnd_t = finishTime - job.arrtime
                        self.waitingTime += job.wait_t
                        self.serviceTime += job.service_t
                        self.turnaroundTime += job.trnd_t
                        self.jobsDone += 1
                        if VERBOSE:
                            print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                                .format(finishTime, job.trnd_t, job.wait_t))
                            print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(env.now,queueLength - 1))
                        
                else:
                    self.jobServing -= 1
                    job.allotment -= pass_time
                    job.remain_t -= pass_time
                    self.queue_1.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority))
    # End handle_queue_1
    
    def handle_queue_2(self, job):    
        print("Enter handle 2")
        with self.cpu.request(priority = job.priority) as req:
            try:
                yield req 
            except simpy.Interrupt as interrupt:
                return 0
            try:
                current_time = self.env.now
                self.jobServing += 1
                if LOGGED:
                    qlog.write( '%.4f\t%d\t%d\n' % (self.env.now, 1 if len(self.queue_2)>0 else 0, len(self.queue_2)) )
                if job.first_response:
                    self.jobsTotal += 1
                    current_t = self.env.now
                    self.first_responsetime += (current_t - job.arrtime)
                    job.first_response = 0
                    if VERBOSE:
                        print("{0:.2f} {1:s} first response time: {2:.2f}".format(env.now, job.name, env.now - job.arrtime))
                    """ if the job is stopped (quantum expired)"""
                if job.remain_t > job.allotment:
                    if VERBOSE:
                        print('Queued 2: ')
                        for i in range(len(self.queue_2)):
                            print(self.queue_2[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' \
                            .format(env.now, job.name, job.arrtime, job.remain_t))
                    yield self.env.timeout(job.allotment)
                    job.remain_t = job.remain_t - job.allotment
                    job.allotment = job.remain_t
                    self.jobServing -= 1
                    self.queue_3.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority + 1))
                    if not self.serversleeping.triggered:
                        self.serversleeping.interrupt( 'Wake up, please.' )
                elif job.remain_t == job.allotment:
                    if VERBOSE:
                        print('Queued 2: ')
                        for i in range(len(self.queue_2)):
                            print(self.queue_2[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' .format(self.env.now, job.name, job.arrtime, job.remain_t))
                    yield self.env.timeout(job.remain_t)
                    self.jobServing -= 1
                    ''' for calculating mean of job in system'''
                    ''' right before the job leaves          '''
                    ''' like 2 2 2 2 2 2 1                   '''
                    ''' mark at this   ^                     '''
                    elapse = self.env.now - self.timeStamp
                    queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing + 1
                    self.numJobsWithTimes.append((queueLength)*(elapse))
                    self.jobsInSysCount.append(queueLength)
                    self.jobsInSysCount_t.append(env.now)
                    self.timeStamp = self.env.now
                    finishTime = env.now
                    job.wait_t = finishTime - job.arrtime - job.service_t
                    job.trnd_t = finishTime - job.arrtime
                    self.waitingTime += job.wait_t
                    self.serviceTime += job.service_t
                    self.turnaroundTime += job.trnd_t
                    self.jobsDone += 1
                    if VERBOSE:
                        print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                            .format(finishTime, job.trnd_t, job.wait_t))
                        print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(env.now,queueLength - 1))
            except simpy.Interrupt as interrupt:
                pass_time = env.now - current_time
                if VERBOSE:
                    print('Queued 2: ')
                    for i in range(len(self.queue_2)):
                        print(self.queue_2[i].name, end=" | ")
                    print('\n')
                    print('{0:s} is preempted at {1:.2f}. The remaining allotment is {2:.2f}'.format(job.name, env.now, job.remain_t - pass_time))
                if env.now - current_time == job.allotment:
                    if job.remain_t > job.allotment:
                        job.remain_t = job.remain_t - job.allotment
                        job.allotment = job.remain_t
                        self.jobServing -= 1
                        self.queue_3.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority + 1))
                        if not self.serversleeping.triggered:
                            self.serversleeping.interrupt( 'Wake up, please.' )
                    elif job.remain_t == job.allotment:
                        self.jobServing -= 1
                        elapse = self.env.now - self.timeStamp
                        queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing + 1
                        self.numJobsWithTimes.append((queueLength)*(elapse))
                        self.jobsInSysCount.append(queueLength)
                        self.jobsInSysCount_t.append(env.now)
                        self.timeStamp = self.env.now
                        finishTime = env.now
                        job.wait_t = finishTime - job.arrtime - job.service_t
                        job.trnd_t = finishTime - job.arrtime
                        self.waitingTime += job.wait_t
                        self.serviceTime += job.service_t
                        self.turnaroundTime += job.trnd_t
                        self.jobsDone += 1
                        if VERBOSE:
                            print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                                .format(finishTime, job.trnd_t, job.wait_t))
                            print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(self.env.now,queueLength - 1))
                else:
                    self.jobServing -= 1
                    job.allotment -= pass_time
                    job.remain_t -= pass_time
                    self.queue_2.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority))
    def handle_queue_3(self, job):   
        print("Enter handle 3")
        
        with self.cpu.request(priority = job.priority) as req:
            try:
                yield req 
            except simpy.Interrupt as interrupt:
                return 0
            try:
                current_time = self.env.now
                self.jobServing += 1
                if LOGGED:
                    qlog.write( '%.4f\t%d\t%d\n' % (self.env.now, 1 if len(self.queue_3)>0 else 0, len(self.queue_3)) )
                if job.first_response:
                    self.jobsTotal += 1
                    current_t = self.env.now
                    self.first_responsetime += (current_t - job.arrtime)
                    job.first_response = 0
                    if VERBOSE:
                        print("{0:.2f} {1:s} first response time: {2:.2f}".format(env.now, job.name, env.now - job.arrtime))
                    """ if the job is stopped (quantum expired)"""
                if job.remain_t > job.allotment:
                    if VERBOSE:
                        print('Queued 3: ')
                        for i in range(len(self.queue_3)):
                            print(self.queue_3[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' \
                            .format(self.env.now, job.name, job.arrtime, job.remain_t))
                    yield self.env.timeout(job.allotment)
                    job.remain_t = job.remain_t - job.allotment
                    job.allotment = job.remain_t
                    self.jobServing -= 1
                    self.queue_3.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority + 1))
                    if not self.serversleeping.triggered:
                        self.serversleeping.interrupt( 'Wake up, please.' )
                elif job.remain_t == job.allotment:
                    if VERBOSE:
                        print('Queued 3: ')
                        for i in range(len(self.queue_3)):
                            print(self.queue_3[i].name, end=" | ")
                        print('\n')
                        print('{0:.2f} serving:{1:s} | arr_t = {2:.2f} | l = {3:.2f}' .format(env.now, job.name, job.arrtime, job.remain_t))
                    yield self.env.timeout(job.remain_t)
                    self.jobServing -= 1
                    ''' for calculating mean of job in system'''
                    ''' right before the job leaves          '''
                    ''' like 2 2 2 2 2 2 1                   '''
                    ''' mark at this   ^                     '''
                    elapse = self.env.now - self.timeStamp
                    queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing + 1
                    self.numJobsWithTimes.append((queueLength)*(elapse))
                    self.jobsInSysCount.append(queueLength)
                    self.jobsInSysCount_t.append(env.now)
                    self.timeStamp = self.env.now
                    finishTime = env.now
                    job.wait_t = finishTime - job.arrtime - job.service_t
                    job.trnd_t = finishTime - job.arrtime
                    self.waitingTime += job.wait_t
                    self.serviceTime += job.service_t
                    self.turnaroundTime += job.trnd_t
                    self.jobsDone += 1
                    if VERBOSE:
                        print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                            .format(finishTime, job.trnd_t, job.wait_t))
                        print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(self.env.now,queueLength - 1))
            except simpy.Interrupt as interrupt:
                pass_time = env.now - current_time
                if VERBOSE:
                    print('Queued 3: ')
                    for i in range(len(self.queue_3)):
                        print(self.queue_3[i].name, end=" | ")
                    print('\n')
                    print('{0:s} is preempted at {1:.2f}. The remaining allotment is {2:.2f}'.format(job.name, env.now, job.remain_t - pass_time))
                if env.now - current_time == job.allotment:
                    if job.remain_t > job.allotment:
                        job.remain_t = job.remain_t - job.allotment
                        job.allotment = job.remain_t
                        self.jobServing -= 1
                        self.queue_3.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority + 1))
                        if not self.serversleeping.triggered:
                            self.serversleeping.interrupt( 'Wake up, please.' )
                    elif job.remain_t == job.allotment:
                        self.jobServing -= 1
                        elapse = self.env.now - self.timeStamp
                        queueLength = len(self.queue_1) + len(self.queue_2) + len(self.queue_3) + self.jobServing + 1
                        self.numJobsWithTimes.append((queueLength)*(elapse))
                        self.jobsInSysCount.append(queueLength)
                        self.jobsInSysCount_t.append(env.now)
                        self.timeStamp = self.env.now
                        finishTime = env.now
                        job.wait_t = finishTime - job.arrtime - job.service_t
                        job.trnd_t = finishTime - job.arrtime
                        self.waitingTime += job.wait_t
                        self.serviceTime += job.service_t
                        self.turnaroundTime += job.trnd_t
                        self.jobsDone += 1
                        if VERBOSE:
                            print(job.name + ': Finish at {0:.2f}, trnd_t = {1:.2f}, wait_t = {2:.2f}' \
                                .format(finishTime, job.trnd_t, job.wait_t))
                            print('{0:.2f} Number of jobs in the system at the time a job finished: {1:d}'.format(self.env.now,queueLength - 1))    
                else:
                    self.jobServing -= 1
                    job.allotment -= pass_time
                    job.remain_t -= pass_time
                    self.queue_3.append(Job(job.name, job.arrtime, job.service_t, job.remain_t, job.allotment, job.first_response, job.priority))
            
    def waiting(self, env):
        try:
            if VERBOSE:
                print( 'Server is idle at %.2f' % self.env.now )
            yield self.env.timeout( MAXSIMTIME )
        except simpy.Interrupt as i:
            if VERBOSE:
                 print('Server waken up and works at %.2f' % self.env.now )
    def timeout(self):
        while True:
            yield self.env.timeout(500)
            self.queue_1 = self.queue_3 + self.queue_2 + self.queue_1
            self.queue_2.clear()
            self.queue_3.clear()

class JobGenerator:
    def __init__(self, env, server, nrjobs = 10000000, lam = 5, mu = 8):
        self.server = server
        self.nrjobs = nrjobs
        self.interarrivaltime = 1/lam
        self.servicetime = 1/mu
        env.process( self.generatejobs(env) )
        env.process( self.job_log(env) )

    def generatejobs(self, env):
        i = 1
        while True:
            ''' yield an event for new job arrival'''
            job_interarrival = int((random.exponential( self.interarrivaltime )))
            yield env.timeout( job_interarrival )

            ''' for calculate mean number of job in system'''
            ''' before the job come                       '''
            ''' like  0 0 0 0 0 1                         '''
            ''' mark at this  ^                           '''
            elapse = env.now-self.server.timeStamp
            queueLength = len(self.server.queue_1) +len(self.server.queue_2)+len(self.server.queue_3) + self.server.jobServing
            self.server.numJobsWithTimes.append((queueLength)*(elapse))
            self.server.jobsInSysCount.append(queueLength)
            self.server.jobsInSysCount_t.append(env.now)
            self.server.timeStamp = env.now

            ''' generate service time and add job to the list'''
            job_duration = int((random.exponential( self.servicetime)))
            self.server.queue_1.append( Job('Job %s' %i, env.now, job_duration, job_duration, job_duration if job_duration < QUANTUM_QUEUE_1 else QUANTUM_QUEUE_1 , 1, 1) )

            if VERBOSE:
                print('{0:.2f} arrive: Job {1:d} | inter-arr_t = {2:.2f} | l = {3:.2f}' \
                    .format(env.now, i, job_interarrival, job_duration))
                print('{0:.2f} Number of job in the system is sampled at arrival:  {1:d}'.format(env.now,queueLength))
                print('Time elapsed form last sample:           {0:.2f}'.format(elapse))
            i += 1

            ''' if server is idle, wake it up'''
            if not self.server.serversleeping.triggered:
                self.server.serversleeping.interrupt( 'Wake up, please.' )

    def job_log(self, env):
        while True:
            if (len(self.server.queue_1) + len(self.server.queue_2) + len(self.server.queue_3) + self.server.jobServing) not in self.server.length:
                self.server.length.append(len(self.server.queue_1) + len(self.server.queue_2) + len(self.server.queue_3) + self.server.jobServing)
            self.server.job_in_sys_count.append(len(self.server.queue_1) + len(self.server.queue_2) + len(self.server.queue_3) + self.server.jobServing)
            yield env.timeout(1);

# %%
env = simpy.Environment()
MyServer = Server( env, SERVICE_DISCIPLINE )
MyJobGenerator = JobGenerator( env, MyServer, POPULATION, LAMBDA, MU )

''' start simulation '''
env.run( until = 200)
# Out:
# Server is idle at 0.00
# 4.00 arrive: Job 1 | inter-arr_t = 4.00 | l = 10.00
# 4.00 Number of job in the system is sampled at arrival:  0
# Time elapsed form last sample:           4.00
# Server waken up and works at 4.00
# 4.00 arrive: Job 2 | inter-arr_t = 0.00 | l = 0.00
# 4.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 1 | Job 2 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Number of jobs in the sys: 1
# Queued 1:
# Job 2 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Enter handle 1
# Server is idle at 4.00
# 4.00 Job 1 first response time: 0.00
# Queued 1:
#
#
# 4.00 serving:Job 1 | arr_t = 4.00 | l = 10.00
# 4.00 Job 2 first response time: 0.00
# Queued 1:
#
#
# 4.00 serving:Job 2 | arr_t = 4.00 | l = 0.00
# Job 2: Finish at 4.00, trnd_t = 0.00, wait_t = 0.00
# 4.00 Number of jobs in the system at the time a job finished: 1
# Server waken up and works at 8.00
# Number of jobs in the sys: 1
# Queued 1:
#
#
# Queued 2:
# Job 1 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 8.00
# Queued 2:
#
#
# 8.00 serving:Job 1 | arr_t = 4.00 | l = 6.00
# Job 1: Finish at 14.00, trnd_t = 10.00, wait_t = 0.00
# 14.00 Number of jobs in the system at the time a job finished: 0
# 17.00 arrive: Job 3 | inter-arr_t = 13.00 | l = 15.00
# 17.00 Number of job in the system is sampled at arrival:  0
# Time elapsed form last sample:           3.00
# Server waken up and works at 17.00
# Number of jobs in the sys: 1
# Queued 1:
# Job 3 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 17.00
# 17.00 Job 3 first response time: 0.00
# Queued 1:
#
#
# 17.00 serving:Job 3 | arr_t = 17.00 | l = 15.00
# 18.00 arrive: Job 4 | inter-arr_t = 1.00 | l = 18.00
# 18.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           1.00
# Server waken up and works at 18.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 4 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 18.00
# 18.00 Job 4 first response time: 0.00
# Queued 1:
#
#
# 18.00 serving:Job 4 | arr_t = 18.00 | l = 18.00
# Server waken up and works at 21.00
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 3 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 21.00
# Queued 2:
#
#
# 21.00 serving:Job 3 | arr_t = 17.00 | l = 11.00
# 22.00 arrive: Job 5 | inter-arr_t = 4.00 | l = 3.00
# 22.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           4.00
# Server waken up and works at 22.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 5 |
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# Enter handle 1
# Enter handle 2
# Server is idle at 22.00
# 22.00 Job 5 first response time: 0.00
# Queued 1:
#
#
# 22.00 serving:Job 5 | arr_t = 22.00 | l = 3.00
# Queued 2:
#
#
# 22.00 serving:Job 4 | arr_t = 18.00 | l = 14.00
# Job 5: Finish at 25.00, trnd_t = 3.00, wait_t = 0.00
# 25.00 Number of jobs in the system at the time a job finished: 2
# 27.00 arrive: Job 6 | inter-arr_t = 5.00 | l = 3.00
# 27.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           2.00
# Server waken up and works at 27.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 6 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 27.00
# 27.00 Job 6 first response time: 0.00
# Queued 1:
#
#
# 27.00 serving:Job 6 | arr_t = 27.00 | l = 3.00
# 28.00 arrive: Job 7 | inter-arr_t = 1.00 | l = 7.00
# 28.00 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           1.00
# Server waken up and works at 28.00
# Number of jobs in the sys: 4
# Queued 1:
# Job 7 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Queued 2:
#
#
# Job 4 is preempted at 28.00. The remaining allotment is 8.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# Enter handle 1
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 4 |
#
# Queued 3:
#
#
# 28.00 Job 7 first response time: 0.00
# Queued 1:
#
#
# 28.00 serving:Job 7 | arr_t = 28.00 | l = 7.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 3 |
#
# Enter handle 2
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 3 |
#
# Queued 2:
#
#
# 29.00 serving:Job 4 | arr_t = 18.00 | l = 8.00
# Job 6: Finish at 30.00, trnd_t = 3.00, wait_t = 0.00
# 30.00 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Server is idle at 30.00
# Queued 3:
#
#
# 30.00 serving:Job 3 | arr_t = 17.00 | l = 3.00
# Server waken up and works at 31.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 4 |
#
# Enter handle 3
# Server is idle at 31.00
# Queued 3:
#
#
# 31.00 serving:Job 4 | arr_t = 18.00 | l = 6.00
# Server waken up and works at 32.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 7 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 32.00
# Queued 2:
#
#
# 32.00 serving:Job 7 | arr_t = 28.00 | l = 3.00
# Job 3: Finish at 33.00, trnd_t = 16.00, wait_t = 1.00
# 33.00 Number of jobs in the system at the time a job finished: 2
# Job 7: Finish at 35.00, trnd_t = 7.00, wait_t = 0.00
# 35.00 Number of jobs in the system at the time a job finished: 1
# Job 4: Finish at 37.00, trnd_t = 19.00, wait_t = 1.00
# 37.00 Number of jobs in the system at the time a job finished: 0
# 50.00 arrive: Job 8 | inter-arr_t = 22.00 | l = 5.00
# 50.00 Number of job in the system is sampled at arrival:  0
# Time elapsed form last sample:           13.00
# Server waken up and works at 50.00
# Number of jobs in the sys: 1
# Queued 1:
# Job 8 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 50.00
# 50.00 Job 8 first response time: 0.00
# Queued 1:
#
#
# 50.00 serving:Job 8 | arr_t = 50.00 | l = 5.00
# 52.00 arrive: Job 9 | inter-arr_t = 2.00 | l = 4.00
# 52.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           2.00
# Server waken up and works at 52.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 9 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 52.00
# 52.00 Job 9 first response time: 0.00
# Queued 1:
#
#
# 52.00 serving:Job 9 | arr_t = 52.00 | l = 4.00
# Server waken up and works at 54.00
# 54.00 arrive: Job 10 | inter-arr_t = 2.00 | l = 7.00
# 54.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           2.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 10 |
#
# Queued 2:
# Job 8 |
#
# Queued 3:
#
#
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 8 |
#
# Queued 3:
#
#
# Enter handle 1
# Enter handle 2
# Server is idle at 54.00
# 54.00 Job 10 first response time: 0.00
# Queued 1:
#
#
# 54.00 serving:Job 10 | arr_t = 54.00 | l = 7.00
# Queued 2:
#
#
# 54.00 serving:Job 8 | arr_t = 50.00 | l = 1.00
# 55.00 arrive: Job 11 | inter-arr_t = 1.00 | l = 14.00
# 55.00 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           1.00
# Server waken up and works at 55.00
# Job 8: Finish at 55.00, trnd_t = 5.00, wait_t = 0.00
# 55.00 Number of jobs in the system at the time a job finished: 3
# Number of jobs in the sys: 3
# Queued 1:
# Job 11 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 55.00
# 55.00 Job 11 first response time: 0.00
# Queued 1:
#
#
# 55.00 serving:Job 11 | arr_t = 55.00 | l = 14.00
# Job 9: Finish at 56.00, trnd_t = 4.00, wait_t = 0.00
# 56.00 Number of jobs in the system at the time a job finished: 2
# 56.00 arrive: Job 12 | inter-arr_t = 1.00 | l = 6.00
# 56.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           0.00
# Server waken up and works at 56.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 12 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 56.00
# 56.00 Job 12 first response time: 0.00
# Queued 1:
#
#
# 56.00 serving:Job 12 | arr_t = 56.00 | l = 6.00
# Server waken up and works at 58.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 10 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 58.00
# Queued 2:
#
#
# 58.00 serving:Job 10 | arr_t = 54.00 | l = 3.00
# Server waken up and works at 59.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 11 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 59.00
# Queued 2:
#
#
# 59.00 serving:Job 11 | arr_t = 55.00 | l = 10.00
# Server waken up and works at 60.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 12 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 60.00
# Queued 2:
#
#
# 60.00 serving:Job 12 | arr_t = 56.00 | l = 2.00
# Job 10: Finish at 61.00, trnd_t = 7.00, wait_t = 0.00
# 61.00 Number of jobs in the system at the time a job finished: 2
# Job 12: Finish at 62.00, trnd_t = 6.00, wait_t = 0.00
# 62.00 Number of jobs in the system at the time a job finished: 1
# 67.00 arrive: Job 13 | inter-arr_t = 11.00 | l = 8.00
# 67.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           5.00
# Server waken up and works at 67.00
# 67.00 arrive: Job 14 | inter-arr_t = 0.00 | l = 0.00
# 67.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 13 | Job 14 |
#
# Queued 2:
#
#
# Queued 3:
# Job 11 |
#
# 67.00 arrive: Job 15 | inter-arr_t = 0.00 | l = 1.00
# 67.00 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 14 | Job 15 |
#
# Queued 2:
#
#
# Queued 3:
# Job 11 |
#
# Enter handle 1
# Number of jobs in the sys: 2
# Queued 1:
# Job 15 |
#
# Queued 2:
#
#
# Queued 3:
# Job 11 |
#
# Enter handle 1
# 67.00 Job 13 first response time: 0.00
# Queued 1:
# Job 15 |
#
# 67.00 serving:Job 13 | arr_t = 67.00 | l = 8.00
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 11 |
#
# Enter handle 1
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 11 |
#
# 67.00 Job 14 first response time: 0.00
# Queued 1:
#
#
# 67.00 serving:Job 14 | arr_t = 67.00 | l = 0.00
# 67.00 Job 15 first response time: 0.00
# Queued 1:
#
#
# 67.00 serving:Job 15 | arr_t = 67.00 | l = 1.00
# Job 14: Finish at 67.00, trnd_t = 0.00, wait_t = 0.00
# 67.00 Number of jobs in the system at the time a job finished: 3
# Enter handle 3
# Server is idle at 67.00
# Queued 3:
#
#
# 67.00 serving:Job 11 | arr_t = 55.00 | l = 2.00
# Job 15: Finish at 68.00, trnd_t = 1.00, wait_t = 0.00
# 68.00 Number of jobs in the system at the time a job finished: 2
# Job 11: Finish at 69.00, trnd_t = 14.00, wait_t = 0.00
# 69.00 Number of jobs in the system at the time a job finished: 1
# 70.00 arrive: Job 16 | inter-arr_t = 3.00 | l = 3.00
# 70.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           1.00
# Server waken up and works at 70.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 16 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 70.00
# 70.00 Job 16 first response time: 0.00
# Queued 1:
#
#
# 70.00 serving:Job 16 | arr_t = 70.00 | l = 3.00
# Server waken up and works at 71.00
# 71.00 arrive: Job 17 | inter-arr_t = 1.00 | l = 7.00
# 71.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           1.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 17 |
#
# Queued 2:
# Job 13 |
#
# Queued 3:
#
#
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 13 |
#
# Queued 3:
#
#
# Enter handle 1
# Enter handle 2
# Server is idle at 71.00
# 71.00 Job 17 first response time: 0.00
# Queued 1:
#
#
# 71.00 serving:Job 17 | arr_t = 71.00 | l = 7.00
# Queued 2:
#
#
# 71.00 serving:Job 13 | arr_t = 67.00 | l = 4.00
# Job 16: Finish at 73.00, trnd_t = 3.00, wait_t = 0.00
# 73.00 Number of jobs in the system at the time a job finished: 2
# Server waken up and works at 75.00
# Job 13: Finish at 75.00, trnd_t = 8.00, wait_t = 0.00
# 75.00 Number of jobs in the system at the time a job finished: 1
# Number of jobs in the sys: 1
# Queued 1:
#
#
# Queued 2:
# Job 17 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 75.00
# Queued 2:
#
#
# 75.00 serving:Job 17 | arr_t = 71.00 | l = 3.00
# 77.00 arrive: Job 18 | inter-arr_t = 6.00 | l = 20.00
# 77.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           2.00
# Server waken up and works at 77.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 18 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 77.00
# 77.00 Job 18 first response time: 0.00
# Queued 1:
#
#
# 77.00 serving:Job 18 | arr_t = 77.00 | l = 20.00
# Job 17: Finish at 78.00, trnd_t = 7.00, wait_t = 0.00
# 78.00 Number of jobs in the system at the time a job finished: 1
# Server waken up and works at 81.00
# Number of jobs in the sys: 1
# Queued 1:
#
#
# Queued 2:
# Job 18 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 81.00
# Queued 2:
#
#
# 81.00 serving:Job 18 | arr_t = 77.00 | l = 16.00
# Server waken up and works at 89.00
# Number of jobs in the sys: 1
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 18 |
#
# Enter handle 3
# Server is idle at 89.00
# Queued 3:
#
#
# 89.00 serving:Job 18 | arr_t = 77.00 | l = 8.00
# 91.00 arrive: Job 19 | inter-arr_t = 14.00 | l = 0.00
# 91.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           13.00
# Server waken up and works at 91.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 19 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 91.00
# 91.00 Job 19 first response time: 0.00
# Queued 1:
#
#
# 91.00 serving:Job 19 | arr_t = 91.00 | l = 0.00
# Job 19: Finish at 91.00, trnd_t = 0.00, wait_t = 0.00
# 91.00 Number of jobs in the system at the time a job finished: 1
# Job 18: Finish at 97.00, trnd_t = 20.00, wait_t = 0.00
# 97.00 Number of jobs in the system at the time a job finished: 0
# 97.00 arrive: Job 20 | inter-arr_t = 6.00 | l = 5.00
# 97.00 Number of job in the system is sampled at arrival:  0
# Time elapsed form last sample:           0.00
# Server waken up and works at 97.00
# Number of jobs in the sys: 1
# Queued 1:
# Job 20 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 97.00
# 97.00 Job 20 first response time: 0.00
# Queued 1:
#
#
# 97.00 serving:Job 20 | arr_t = 97.00 | l = 5.00
# 98.00 arrive: Job 21 | inter-arr_t = 1.00 | l = 6.00
# 98.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           1.00
# Server waken up and works at 98.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 21 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 98.00
# 98.00 Job 21 first response time: 0.00
# Queued 1:
#
#
# 98.00 serving:Job 21 | arr_t = 98.00 | l = 6.00
# 100.00 arrive: Job 22 | inter-arr_t = 2.00 | l = 3.00
# 100.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           2.00
# Server waken up and works at 100.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 22 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 100.00
# 100.00 Job 22 first response time: 0.00
# Queued 1:
#
#
# 100.00 serving:Job 22 | arr_t = 100.00 | l = 3.00
# Server waken up and works at 101.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 20 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 101.00
# Queued 2:
#
#
# 101.00 serving:Job 20 | arr_t = 97.00 | l = 1.00
# Server waken up and works at 102.00
# Job 20: Finish at 102.00, trnd_t = 5.00, wait_t = 0.00
# 102.00 Number of jobs in the system at the time a job finished: 2
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 21 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 102.00
# Queued 2:
#
#
# 102.00 serving:Job 21 | arr_t = 98.00 | l = 2.00
# Job 22: Finish at 103.00, trnd_t = 3.00, wait_t = 0.00
# 103.00 Number of jobs in the system at the time a job finished: 1
# Job 21: Finish at 104.00, trnd_t = 6.00, wait_t = 0.00
# 104.00 Number of jobs in the system at the time a job finished: 0
# 117.00 arrive: Job 23 | inter-arr_t = 17.00 | l = 8.00
# 117.00 Number of job in the system is sampled at arrival:  0
# Time elapsed form last sample:           13.00
# Server waken up and works at 117.00
# Number of jobs in the sys: 1
# Queued 1:
# Job 23 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 117.00
# 117.00 Job 23 first response time: 0.00
# Queued 1:
#
#
# 117.00 serving:Job 23 | arr_t = 117.00 | l = 8.00
# 118.00 arrive: Job 24 | inter-arr_t = 1.00 | l = 60.00
# 118.00 Number of job in the system is sampled at arrival:  1
# Time elapsed form last sample:           1.00
# Server waken up and works at 118.00
# Number of jobs in the sys: 2
# Queued 1:
# Job 24 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 118.00
# 118.00 Job 24 first response time: 0.00
# Queued 1:
#
#
# 118.00 serving:Job 24 | arr_t = 118.00 | l = 60.00
# Server waken up and works at 121.00
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 23 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 121.00
# Queued 2:
#
#
# 121.00 serving:Job 23 | arr_t = 117.00 | l = 4.00
# Server waken up and works at 122.00
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
# Job 24 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 122.00
# Queued 2:
#
#
# 122.00 serving:Job 24 | arr_t = 118.00 | l = 56.00
# 124.00 arrive: Job 25 | inter-arr_t = 6.00 | l = 41.00
# 124.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           6.00
# Server waken up and works at 124.00
# 124.00 arrive: Job 26 | inter-arr_t = 0.00 | l = 7.00
# 124.00 Number of job in the system is sampled at arrival:  3
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 4
# Queued 1:
# Job 25 | Job 26 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# 124.00 arrive: Job 27 | inter-arr_t = 0.00 | l = 15.00
# 124.00 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 4
# Queued 1:
# Job 26 | Job 27 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Queued 2:
#
#
# Job 24 is preempted at 124.00. The remaining allotment is 54.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 27 |
#
# Queued 2:
# Job 24 |
#
# Queued 3:
#
#
# Enter handle 1
# Queued 2:
# Job 24 |
#
# Job 23 is preempted at 124.00. The remaining allotment is 1.00
# 124.00 Job 25 first response time: 0.00
# Queued 1:
# Job 27 |
#
# 124.00 serving:Job 25 | arr_t = 124.00 | l = 41.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 24 | Job 23 |
#
# Queued 3:
#
#
# Enter handle 1
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 24 | Job 23 |
#
# Queued 3:
#
#
# 124.00 Job 26 first response time: 0.00
# Queued 1:
#
#
# 124.00 serving:Job 26 | arr_t = 124.00 | l = 7.00
# 124.00 Job 27 first response time: 0.00
# Queued 1:
#
#
# 124.00 serving:Job 27 | arr_t = 124.00 | l = 15.00
# 128.00 arrive: Job 28 | inter-arr_t = 4.00 | l = 14.00
# 128.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           4.00
# 128.00 arrive: Job 29 | inter-arr_t = 0.00 | l = 1.00
# 128.00 Number of job in the system is sampled at arrival:  6
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 6
# Queued 1:
# Job 28 | Job 29 |
#
# Queued 2:
# Job 23 | Job 25 | Job 26 | Job 27 |
#
# Queued 3:
#
#
# Enter handle 2
# Number of jobs in the sys: 5
# Queued 1:
# Job 29 |
#
# Queued 2:
# Job 23 | Job 25 | Job 26 | Job 27 |
#
# Queued 3:
#
#
# Enter handle 1
# Queued 2:
# Job 23 | Job 25 | Job 26 | Job 27 |
#
# 128.00 serving:Job 24 | arr_t = 118.00 | l = 54.00
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 23 | Job 25 | Job 26 | Job 27 |
#
# Queued 3:
#
#
# Enter handle 1
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 23 | Job 25 | Job 26 | Job 27 |
#
# Queued 3:
#
#
# 128.00 Job 28 first response time: 0.00
# Queued 1:
#
#
# 128.00 serving:Job 28 | arr_t = 128.00 | l = 14.00
# 128.00 Job 29 first response time: 0.00
# Queued 1:
#
#
# 128.00 serving:Job 29 | arr_t = 128.00 | l = 1.00
# Job 29: Finish at 129.00, trnd_t = 1.00, wait_t = 0.00
# 129.00 Number of jobs in the system at the time a job finished: 6
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 25 | Job 26 | Job 27 |
#
# Queued 3:
#
#
# Enter handle 2
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 26 | Job 27 |
#
# Queued 3:
#
#
# Enter handle 2
# Queued 2:
# Job 26 | Job 27 |
#
# 129.00 serving:Job 23 | arr_t = 117.00 | l = 1.00
# Job 23: Finish at 130.00, trnd_t = 13.00, wait_t = 5.00
# 130.00 Number of jobs in the system at the time a job finished: 4
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 27 |
#
# Queued 3:
#
#
# Enter handle 2
# Queued 2:
# Job 27 |
#
# 130.00 serving:Job 25 | arr_t = 124.00 | l = 37.00
# 132.00 arrive: Job 30 | inter-arr_t = 4.00 | l = 21.00
# 132.00 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           2.00
# 132.00 arrive: Job 31 | inter-arr_t = 0.00 | l = 11.00
# 132.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 5
# Queued 1:
# Job 30 | Job 31 |
#
# Queued 2:
# Job 28 |
#
# Queued 3:
#
#
# Enter handle 2
# Number of jobs in the sys: 4
# Queued 1:
# Job 31 |
#
# Queued 2:
# Job 28 |
#
# Queued 3:
#
#
# Enter handle 1
# Queued 2:
# Job 28 |
#
# Job 25 is preempted at 132.00. The remaining allotment is 35.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 28 | Job 25 |
#
# Queued 3:
#
#
# Enter handle 1
# 132.00 Job 30 first response time: 0.00
# Queued 1:
#
#
# 132.00 serving:Job 30 | arr_t = 132.00 | l = 21.00
# 132.00 Job 31 first response time: 0.00
# Queued 1:
#
#
# 132.00 serving:Job 31 | arr_t = 132.00 | l = 11.00
# 134.00 arrive: Job 32 | inter-arr_t = 2.00 | l = 14.00
# 134.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           2.00
# Queued 2:
# Job 28 | Job 25 |
#
# 134.00 serving:Job 27 | arr_t = 124.00 | l = 11.00
# Number of jobs in the sys: 6
# Queued 1:
# Job 32 |
#
# Queued 2:
# Job 25 | Job 30 | Job 31 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 2
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 25 | Job 30 | Job 31 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 1
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 25 | Job 30 | Job 31 |
#
# Queued 3:
# Job 24 |
#
# Queued 2:
# Job 25 | Job 30 | Job 31 |
#
# 136.00 serving:Job 28 | arr_t = 128.00 | l = 10.00
# 136.00 Job 32 first response time: 2.00
# Queued 1:
#
#
# 136.00 serving:Job 32 | arr_t = 134.00 | l = 14.00
# 137.00 arrive: Job 33 | inter-arr_t = 3.00 | l = 5.00
# 137.00 Number of job in the system is sampled at arrival:  7
# Time elapsed form last sample:           3.00
# 138.00 arrive: Job 34 | inter-arr_t = 1.00 | l = 27.00
# 138.00 Number of job in the system is sampled at arrival:  8
# Time elapsed form last sample:           1.00
# 138.00 arrive: Job 35 | inter-arr_t = 0.00 | l = 5.00
# 138.00 Number of job in the system is sampled at arrival:  9
# Time elapsed form last sample:           0.00
# 140.00 arrive: Job 36 | inter-arr_t = 2.00 | l = 0.00
# 140.00 Number of job in the system is sampled at arrival:  10
# Time elapsed form last sample:           2.00
# 140.00 arrive: Job 37 | inter-arr_t = 0.00 | l = 6.00
# 140.00 Number of job in the system is sampled at arrival:  11
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 11
# Queued 1:
# Job 33 | Job 34 | Job 35 | Job 36 | Job 37 |
#
# Queued 2:
# Job 30 | Job 31 | Job 32 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 2
# Number of jobs in the sys: 10
# Queued 1:
# Job 34 | Job 35 | Job 36 | Job 37 |
#
# Queued 2:
# Job 30 | Job 31 | Job 32 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 1
# Queued 2:
# Job 30 | Job 31 | Job 32 |
#
# Job 28 is preempted at 140.00. The remaining allotment is 6.00
# Number of jobs in the sys: 9
# Queued 1:
# Job 35 | Job 36 | Job 37 |
#
# Queued 2:
# Job 30 | Job 31 | Job 32 | Job 28 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 1
# Queued 2:
# Job 30 | Job 31 | Job 32 | Job 28 |
#
# Job 27 is preempted at 140.00. The remaining allotment is 5.00
# 140.00 Job 33 first response time: 3.00
# Queued 1:
# Job 35 | Job 36 | Job 37 |
#
# 140.00 serving:Job 33 | arr_t = 137.00 | l = 5.00
# Number of jobs in the sys: 9
# Queued 1:
# Job 36 | Job 37 |
#
# Queued 2:
# Job 30 | Job 31 | Job 32 | Job 28 | Job 27 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 1
# 140.00 Job 34 first response time: 2.00
# Queued 1:
# Job 36 | Job 37 |
#
# 140.00 serving:Job 34 | arr_t = 138.00 | l = 27.00
# Number of jobs in the sys: 9
# Queued 1:
# Job 37 |
#
# Queued 2:
# Job 30 | Job 31 | Job 32 | Job 28 | Job 27 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 1
# 140.00 Job 35 first response time: 2.00
# Queued 1:
# Job 37 |
#
# 140.00 serving:Job 35 | arr_t = 138.00 | l = 5.00
# Number of jobs in the sys: 9
# Queued 1:
#
#
# Queued 2:
# Job 30 | Job 31 | Job 32 | Job 28 | Job 27 | Job 33 | Job 34 | Job 35 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 1
# Number of jobs in the sys: 9
# Queued 1:
#
#
# Queued 2:
# Job 30 | Job 31 | Job 32 | Job 28 | Job 27 | Job 33 | Job 34 | Job 35 |
#
# Queued 3:
# Job 24 |
#
# 144.00 Job 36 first response time: 4.00
# Queued 1:
#
#
# 144.00 serving:Job 36 | arr_t = 140.00 | l = 0.00
# Queued 2:
# Job 30 | Job 31 | Job 32 | Job 28 | Job 27 | Job 33 | Job 34 | Job 35 |
#
# 144.00 serving:Job 25 | arr_t = 124.00 | l = 35.00
# 144.00 Job 37 first response time: 4.00
# Queued 1:
#
#
# 144.00 serving:Job 37 | arr_t = 140.00 | l = 6.00
# Job 36: Finish at 144.00, trnd_t = 4.00, wait_t = 4.00
# 144.00 Number of jobs in the system at the time a job finished: 11
# Number of jobs in the sys: 10
# Queued 1:
#
#
# Queued 2:
# Job 31 | Job 32 | Job 28 | Job 27 | Job 33 | Job 34 | Job 35 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 2
# Number of jobs in the sys: 9
# Queued 1:
#
#
# Queued 2:
# Job 32 | Job 28 | Job 27 | Job 33 | Job 34 | Job 35 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 2
# Queued 2:
# Job 32 | Job 28 | Job 27 | Job 33 | Job 34 | Job 35 |
#
# 144.00 serving:Job 30 | arr_t = 132.00 | l = 17.00
# Number of jobs in the sys: 9
# Queued 1:
#
#
# Queued 2:
# Job 28 | Job 27 | Job 33 | Job 34 | Job 35 | Job 37 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 2
# Queued 2:
# Job 28 | Job 27 | Job 33 | Job 34 | Job 35 | Job 37 |
#
# 148.00 serving:Job 31 | arr_t = 132.00 | l = 7.00
# Number of jobs in the sys: 9
# Queued 1:
#
#
# Queued 2:
# Job 27 | Job 33 | Job 34 | Job 35 | Job 37 |
#
# Queued 3:
# Job 24 | Job 25 |
#
# Enter handle 2
# Queued 2:
# Job 27 | Job 33 | Job 34 | Job 35 | Job 37 |
#
# 150.00 serving:Job 32 | arr_t = 134.00 | l = 10.00
# Number of jobs in the sys: 9
# Queued 1:
#
#
# Queued 2:
# Job 33 | Job 34 | Job 35 | Job 37 |
#
# Queued 3:
# Job 24 | Job 25 | Job 30 |
#
# Enter handle 2
# Queued 2:
# Job 33 | Job 34 | Job 35 | Job 37 |
#
# 152.00 serving:Job 28 | arr_t = 128.00 | l = 6.00
# 153.00 arrive: Job 38 | inter-arr_t = 13.00 | l = 3.00
# 153.00 Number of job in the system is sampled at arrival:  10
# Time elapsed form last sample:           9.00
# Job 31: Finish at 155.00, trnd_t = 23.00, wait_t = 12.00
# 155.00 Number of jobs in the system at the time a job finished: 10
# Number of jobs in the sys: 9
# Queued 1:
# Job 38 |
#
# Queued 2:
# Job 34 | Job 35 | Job 37 |
#
# Queued 3:
# Job 24 | Job 25 | Job 30 |
#
# Enter handle 2
# Number of jobs in the sys: 8
# Queued 1:
#
#
# Queued 2:
# Job 34 | Job 35 | Job 37 |
#
# Queued 3:
# Job 24 | Job 25 | Job 30 |
#
# Enter handle 1
# 155.00 Job 38 first response time: 2.00
# Queued 1:
#
#
# 155.00 serving:Job 38 | arr_t = 153.00 | l = 3.00
# Queued 2:
# Job 34 | Job 35 | Job 37 |
#
# 156.00 serving:Job 33 | arr_t = 137.00 | l = 1.00
# 157.00 arrive: Job 39 | inter-arr_t = 4.00 | l = 12.00
# 157.00 Number of job in the system is sampled at arrival:  10
# Time elapsed form last sample:           2.00
# Job 33: Finish at 157.00, trnd_t = 20.00, wait_t = 15.00
# 157.00 Number of jobs in the system at the time a job finished: 10
# Number of jobs in the sys: 9
# Queued 1:
# Job 39 |
#
# Queued 2:
# Job 35 | Job 37 |
#
# Queued 3:
# Job 24 | Job 25 | Job 30 | Job 28 |
#
# Enter handle 2
# Number of jobs in the sys: 8
# Queued 1:
#
#
# Queued 2:
# Job 35 | Job 37 |
#
# Queued 3:
# Job 24 | Job 25 | Job 30 | Job 28 |
#
# Enter handle 1
# 157.00 Job 39 first response time: 0.00
# Queued 1:
#
#
# 157.00 serving:Job 39 | arr_t = 157.00 | l = 12.00
# Job 38: Finish at 158.00, trnd_t = 5.00, wait_t = 2.00
# 158.00 Number of jobs in the system at the time a job finished: 8
# Number of jobs in the sys: 7
# Queued 1:
#
#
# Queued 2:
# Job 37 |
#
# Queued 3:
# Job 24 | Job 25 | Job 30 | Job 28 | Job 32 |
#
# Enter handle 2
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 24 | Job 25 | Job 30 | Job 28 | Job 32 |
#
# Enter handle 2
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 24 | Job 25 | Job 30 | Job 28 | Job 32 |
#
# Queued 2:
#
#
# 158.00 serving:Job 35 | arr_t = 138.00 | l = 1.00
# Queued 2:
#
#
# 158.00 serving:Job 37 | arr_t = 140.00 | l = 2.00
# Job 35: Finish at 159.00, trnd_t = 21.00, wait_t = 16.00
# 159.00 Number of jobs in the system at the time a job finished: 7
# Number of jobs in the sys: 6
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 25 | Job 30 | Job 28 | Job 32 |
#
# Enter handle 3
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 30 | Job 28 | Job 32 |
#
# Enter handle 3
# Queued 3:
# Job 30 | Job 28 | Job 32 |
#
# 159.00 serving:Job 24 | arr_t = 118.00 | l = 48.00
# Job 37: Finish at 160.00, trnd_t = 20.00, wait_t = 14.00
# 160.00 Number of jobs in the system at the time a job finished: 5
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 28 | Job 32 |
#
# Enter handle 3
# Queued 3:
# Job 28 | Job 32 |
#
# 160.00 serving:Job 25 | arr_t = 124.00 | l = 29.00
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 39 |
#
# Queued 3:
# Job 32 |
#
# Enter handle 3
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 32 |
#
# Enter handle 2
# Queued 2:
#
#
# 161.00 serving:Job 39 | arr_t = 157.00 | l = 8.00
# 163.00 arrive: Job 40 | inter-arr_t = 6.00 | l = 4.00
# 163.00 Number of job in the system is sampled at arrival:  4
# Time elapsed form last sample:           3.00
# Job 39: Finish at 169.00, trnd_t = 12.00, wait_t = 0.00
# 169.00 Number of jobs in the system at the time a job finished: 4
# Queued 3:
# Job 32 |
#
# 169.00 serving:Job 28 | arr_t = 128.00 | l = 2.00
# 171.00 arrive: Job 41 | inter-arr_t = 8.00 | l = 9.00
# 171.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           2.00
# Job 28: Finish at 171.00, trnd_t = 43.00, wait_t = 29.00
# 171.00 Number of jobs in the system at the time a job finished: 5
# 171.00 arrive: Job 42 | inter-arr_t = 0.00 | l = 10.00
# 171.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           0.00
# 171.00 arrive: Job 43 | inter-arr_t = 0.00 | l = 4.00
# 171.00 Number of job in the system is sampled at arrival:  6
# Time elapsed form last sample:           0.00
# Number of jobs in the sys: 6
# Queued 1:
# Job 40 | Job 41 | Job 42 | Job 43 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 3
# Number of jobs in the sys: 5
# Queued 1:
# Job 41 | Job 42 | Job 43 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Queued 3:
#
#
# Job 25 is preempted at 171.00. The remaining allotment is 18.00
# Number of jobs in the sys: 4
# Queued 1:
# Job 42 | Job 43 |
#
# Queued 2:
#
#
# Queued 3:
# Job 25 |
#
# Enter handle 1
# Queued 3:
# Job 25 |
#
# Job 24 is preempted at 171.00. The remaining allotment is 36.00
# 171.00 Job 40 first response time: 8.00
# Queued 1:
# Job 42 | Job 43 |
#
# 171.00 serving:Job 40 | arr_t = 163.00 | l = 4.00
# Number of jobs in the sys: 4
# Queued 1:
# Job 43 |
#
# Queued 2:
#
#
# Queued 3:
# Job 25 | Job 24 |
#
# Enter handle 1
# 171.00 Job 41 first response time: 0.00
# Queued 1:
# Job 43 |
#
# 171.00 serving:Job 41 | arr_t = 171.00 | l = 9.00
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 25 | Job 24 |
#
# Enter handle 1
# 171.00 Job 42 first response time: 0.00
# Queued 1:
#
#
# 171.00 serving:Job 42 | arr_t = 171.00 | l = 10.00
# 174.00 arrive: Job 44 | inter-arr_t = 3.00 | l = 7.00
# 174.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           3.00
# Job 40: Finish at 175.00, trnd_t = 12.00, wait_t = 8.00
# 175.00 Number of jobs in the system at the time a job finished: 5
# 175.00 Job 43 first response time: 4.00
# Queued 1:
# Job 44 |
#
# 175.00 serving:Job 43 | arr_t = 171.00 | l = 4.00
# Queued 3:
# Job 25 | Job 24 |
#
# 175.00 serving:Job 32 | arr_t = 134.00 | l = 2.00
# Number of jobs in the sys: 6
# Queued 1:
# Job 44 |
#
# Queued 2:
# Job 41 | Job 42 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 3
# Number of jobs in the sys: 5
# Queued 1:
#
#
# Queued 2:
# Job 41 | Job 42 |
#
# Queued 3:
# Job 24 |
#
# Enter handle 1
# Queued 3:
# Job 24 |
#
# Job 32 is preempted at 175.00. The remaining allotment is 2.00
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 42 |
#
# Queued 3:
# Job 24 | Job 32 |
#
# Enter handle 2
# 175.00 Job 44 first response time: 1.00
# Queued 1:
#
#
# 175.00 serving:Job 44 | arr_t = 174.00 | l = 7.00
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 24 | Job 32 |
#
# Enter handle 2
# Queued 2:
#
#
# 175.00 serving:Job 41 | arr_t = 171.00 | l = 5.00
# 177.00 arrive: Job 45 | inter-arr_t = 3.00 | l = 31.00
# 177.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           2.00
# Job 43: Finish at 179.00, trnd_t = 8.00, wait_t = 4.00
# 179.00 Number of jobs in the system at the time a job finished: 5
# Queued 2:
# Job 44 |
#
# 179.00 serving:Job 42 | arr_t = 171.00 | l = 6.00
# Queued 3:
# Job 24 | Job 32 |
#
# 179.00 serving:Job 25 | arr_t = 124.00 | l = 18.00
# Job 41: Finish at 180.00, trnd_t = 9.00, wait_t = 0.00
# 180.00 Number of jobs in the system at the time a job finished: 6
# Number of jobs in the sys: 5
# Queued 1:
# Job 45 |
#
# Queued 2:
# Job 44 |
#
# Queued 3:
# Job 32 |
#
# Enter handle 3
# Number of jobs in the sys: 4
# Queued 1:
#
#
# Queued 2:
# Job 44 |
#
# Queued 3:
# Job 32 |
#
# Enter handle 1
# Queued 3:
# Job 32 |
#
# Job 25 is preempted at 180.00. The remaining allotment is 17.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 32 | Job 25 |
#
# Enter handle 2
# 180.00 Job 45 first response time: 3.00
# Queued 1:
#
#
# 180.00 serving:Job 45 | arr_t = 177.00 | l = 31.00
# Queued 2:
#
#
# 180.00 serving:Job 44 | arr_t = 174.00 | l = 3.00
# 181.00 arrive: Job 46 | inter-arr_t = 4.00 | l = 7.00
# 181.00 Number of job in the system is sampled at arrival:  5
# Time elapsed form last sample:           1.00
# Job 44: Finish at 183.00, trnd_t = 9.00, wait_t = 2.00
# 183.00 Number of jobs in the system at the time a job finished: 5
# Number of jobs in the sys: 4
# Queued 1:
# Job 46 |
#
# Queued 2:
#
#
# Queued 3:
# Job 25 |
#
# Enter handle 3
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 25 |
#
# Enter handle 1
# 183.00 Job 46 first response time: 2.00
# Queued 1:
#
#
# 183.00 serving:Job 46 | arr_t = 181.00 | l = 7.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 45 |
#
# Queued 3:
#
#
# Enter handle 3
# Enter handle 2
# Server is idle at 184.00
# Queued 2:
#
#
# 184.00 serving:Job 45 | arr_t = 177.00 | l = 27.00
# Job 42: Finish at 185.00, trnd_t = 14.00, wait_t = 4.00
# 185.00 Number of jobs in the system at the time a job finished: 2
# Queued 3:
#
#
# 185.00 serving:Job 25 | arr_t = 124.00 | l = 17.00
# Server waken up and works at 187.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 46 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 187.00
# Queued 2:
#
#
# 187.00 serving:Job 46 | arr_t = 181.00 | l = 3.00
# Job 46: Finish at 190.00, trnd_t = 9.00, wait_t = 2.00
# 190.00 Number of jobs in the system at the time a job finished: 2
# Server waken up and works at 192.00
# Number of jobs in the sys: 2
# Queued 1:
#
#
# Queued 2:
#
#
# Queued 3:
# Job 45 |
#
# Enter handle 3
# Server is idle at 192.00
# Queued 3:
#
#
# 192.00 serving:Job 45 | arr_t = 177.00 | l = 19.00
# 195.00 arrive: Job 47 | inter-arr_t = 14.00 | l = 16.00
# 195.00 Number of job in the system is sampled at arrival:  2
# Time elapsed form last sample:           5.00
# Server waken up and works at 195.00
# Number of jobs in the sys: 3
# Queued 1:
# Job 47 |
#
# Queued 2:
#
#
# Queued 3:
#
#
# Enter handle 1
# Server is idle at 195.00
# 195.00 Job 47 first response time: 0.00
# Queued 1:
#
#
# 195.00 serving:Job 47 | arr_t = 195.00 | l = 16.00
# Server waken up and works at 199.00
# Number of jobs in the sys: 3
# Queued 1:
#
#
# Queued 2:
# Job 47 |
#
# Queued 3:
#
#
# Enter handle 2
# Server is idle at 199.00
# Queued 2:
#
#
# 199.00 serving:Job 47 | arr_t = 195.00 | l = 12.00
